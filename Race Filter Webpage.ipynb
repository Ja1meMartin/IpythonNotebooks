# %%
import lxml.etree
import lxml.html
import urllib2

# %%
course = "Red"
url = urllib2.urlopen("http://www.racingpost.com/horses2/cards/card.sd?race_id=581305")
content = url.read()
soup = lxml.html.fromstring(content)
print soup
# Out:
# <Element html at 0x2ab0ad0>

# %%
horses = soup.findall(".//tr[@class='cr']")
print len(horses)
#course = soup.find(".//tr//b[@class='black']//a")

print course
# Out:
# 12
# Red

# %%
data = horses[1]
for td in data:
    text = td.text_content().split()
    print text, "---",type(text)
# Out:
# ['29', '0080-'] --- <type 'list'>
# [] --- <type 'list'>
# ['DELIBERATION', '315'] --- <type 'list'>
# ['5'] --- <type 'list'>
# ['9-6', '58'] --- <type 'list'>
# ['Michael', "O'Connell", 'John', 'Quinn71'] --- <type 'list'>
# ['25'] --- <type 'list'>
# ['60'] --- <type 'list'>
# [] --- <type 'list'>

# %% [markdown]
# ### But can I get the link

# %%
#link = data.iterlinks()
#print link.next(), type(link.next())
#print link.next(), type(link.next())
print "a"
import Horse
import Race

#print link.next(), type(link.next())
def createHorse(iters):
    
    it = iters.iterlinks()
    
    l = it.next()
    print l
    
    l = it.next()
    print l
    
    l = it.next()
    print l, l[2]
    
    return Horse.Horse.factory(l[2])

hs = [createHorse(h) for h in horses]
# Out:
# a
# (<Element a at 0x2b15230>, 'href', 'http://www.racingpost.com/horses/owner_home.sd?owner_id=84735', 0)
# (<Element img at 0x2b150b0>, 'src', 'http://images.racingpost.com/png_silks/b/5/3/84735b.png', 0)
# (<Element a at 0x2b15230>, 'href', 'http://www.racingpost.com/horses/horse_home.sd?race_id=581305&r_date=2013-06-06&horse_id=788231', 0) http://www.racingpost.com/horses/horse_home.sd?race_id=581305&r_date=2013-06-06&horse_id=788231
# prevalue
#  ['Red', '7Hy', 'C53yHc', '2K']
# value: 2K 2
# prevalue ['Pon', '8GS', 'C53yMd', '2K']
# 21
# value: 2K 2
# prevalue ['Bev', '7GF', 'C53yHc', '2K']
# 10
# value: 2K 2
# prevalue ['Thi', '8Sft', 'C5Md', '2K']
# value: 2K 2
# prevalue ['Red', '8GS', 'C62yMd', '1K']
# value: 1K 1
# prevalue ['Pon', '6GF', 'C42yMd', '4K']
# value: 4K 4
# prevalue ['Red', '7GF', 'C52yMd', '2K']
# 13
# value: 2K 2
# Crossley is my name
# (<Element a at 0x2b15890>, 'href', 'http://www.racingpost.com/horses/owner_home.sd?owner_id=202559', 0)
# (<Element img at 0x2b15230>, 'src', 'http://images.racingpost.com/png_silks/9/5/5/202559.png', 0)
# (<Element a at 0x2b15890>, 'href', 'http://www.racingpost.com/horses/horse_home.sd?race_id=581305&r_date=2013-06-06&horse_id=769578', 0) http://www.racingpost.com/horses/horse_home.sd?race_id=581305&r_date=2013-06-06&horse_id=769578
# prevalue
#  ['Don', '6GF', 'C5Hc', '2K']
# value: 2K 2
# prevalue ['Chs', '6GF', 'C5Hc', '4K']
# 38
# value: 4K 4
# prevalue ['Don', '6Gd', 'C4Hc', '5K']
# 14
# value: 5K 5
# prevalue ['Don', '5Hy', 'C4Hc', '4K']
# value: 4K 4
# prevalue ['Kem', '8St', 'C63yCl', '1K']
# 13
# value: 1K 1
# prevalue ['Sth', '6St', 'C6Cl', '1K']
# value: 1K 1
# prevalue ['Sth', '6St', 'C6Hc', '1K']
# 11
# value: 1K 1
# prevalue ['Don', '7Sft', 'C5Hc', '2K']
# value: 2K 2
# prevalue ['Wol', '6St', 'C5Hc', '1K']
# value: 1K 1
# prevalue ['Cat', '6Sft', 'C53yHc', '2K']
# value: 2K 2
# prevalue ['Ham', '6Sft', 'C53yHc', '2K']
# value: 2K 2
# prevalue ['Eps', '6GS', 'C53yHc', '3K']
# 1
# value: 3K 3
# prevalue ['Ham', '6GS', 'C63yHc', '1K']
# value: 1K 1
# prevalue ['Ham', '6Gd', 'C63yHc', '1K']
# value: 1K 1
# prevalue ['Cat', '7Gd', 'C63yHc', '2K']
# value: 2K 2
# prevalue ['Ham', '6Gd', 'C6MdSl', '2K']
# 2
# value: 2K 2
# prevalue ['Sth', '6St', 'C53yMd', '1K']
# 34
# value: 1K 1
# prevalue ['Sth', '5St', 'C6Md', '1K']
# 18
# value: 1K 1
# prevalue ['Cat', '6GS', 'C62yMd', '2K']
# value: 2K 2
# Deliberation is my name
# (<Element a at 0x2b156b0>, 'href', 'http://www.racingpost.com/horses/owner_home.sd?owner_id=91537', 0)
# (<Element img at 0x2b15fb0>, 'src', 'http://images.racingpost.com/png_silks/7/3/5/91537.png', 0)
# (<Element a at 0x2b156b0>, 'href', 'http://www.racingpost.com/horses/horse_home.sd?race_id=581305&r_date=2013-06-06&horse_id=744950', 0) http://www.racingpost.com/horses/horse_home.sd?race_id=581305&r_date=2013-06-06&horse_id=744950
# prevalue
#  ['Ncs', '8Gd', 'C5Hc', '2K']
# value: 2K 2
# prevalue ['Ncs', '8Gd', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Wol', '9St', 'C6Hc', '2K']
# 5
# value: 2K 2
# prevalue ['Wol', '9St', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Ncs', '7Gd', 'C6Hc', '1K']
# h
# value: 1K 1
# prevalue ['Bev', '10Gd', 'C6Hc', '2K']
# 20
# value: 2K 2
# prevalue ['Red', '8Gd', 'C6Hc', '1K']
# 13
# value: 1K 1
# prevalue ['Rip', '8GS', 'C6Hc', '2K']
# 21
# value: 2K 2
# prevalue ['Ncs', '8GF', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Red', '7GF', 'C5Hc', '2K']
# value: 2K 2
# prevalue ['Don', '17GS', 'C44yH', '2K']
# Moos
# value: 2K 2
# position PU
# prevalue ['Wol', '9St', 'C5Hc', '2K']
# value: 2K 2
# prevalue ['Wol', '9St', 'C6Hc', '1K']
# 1
# value: 1K 1
# prevalue ['Ncs', '8Gd', 'C63yHc', '2K']
# value: 2K 2
# prevalue ['Red', '8GF', 'C63yHc', '1K']
# value: 1K 1
# prevalue ['Not', '8GF', 'C63yHc', '2K']
# 22
# value: 2K 2
# prevalue ['Wol', '7St', 'C53yMd', '2K']
# 13
# value: 2K 2
# prevalue ['Wol', '7St', 'C5Md', '2K']
# value: 2K 2
# prevalue ['Don', '7Gd', 'C42yMd', '4K']
# 31
# value: 4K 4
# Cross The Boss is my name
# (<Element a at 0x2b15ad0>, 'href', 'http://www.racingpost.com/horses/owner_home.sd?owner_id=202645', 0)
# (<Element img at 0x2b15d10>, 'src', 'http://images.racingpost.com/png_silks/5/4/6/202645.png', 0)
# (<Element a at 0x2b15ad0>, 'href', 'http://www.racingpost.com/horses/horse_home.sd?race_id=581305&r_date=2013-06-06&horse_id=790691', 0) http://www.racingpost.com/horses/horse_home.sd?race_id=581305&r_date=2013-06-06&horse_id=790691
# prevalue
#  ['Bat', '8Fm', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Wol', '9St', 'C5Hc', '2K']
# value: 2K 2
# prevalue ['Lin', '8St', 'C5Hc', '2K']
# value: 2K 2
# prevalue ['Wol', '9St', 'C6Cl', '1K']
# value: 1K 1
# prevalue ['Lin', '7St', 'C5Hc', '2K']
# value: 2K 2
# prevalue ['Wol', '7St', 'C5Hc', '2K']
# value: 2K 2
# prevalue ['Wol', '7St', 'C5Hc', '2K']
# 3
# value: 2K 2
# prevalue ['Lin', '6St', 'C6Cl', '1K']
# value: 1K 1
# prevalue ['Wol', '6St', 'C5Hc', '2K']
# value: 2K 2
# prevalue ['Wol', '6St', 'C5Hc', '2K']
# 13
# value: 2K 2
# prevalue ['Lin', '5St/Slw', 'C5Hc', '2K']
# value: 2K 2
# prevalue ['Wol', '5St', 'C5Hc', '2K']
# value: 2K 2
# prevalue ['Wol', '6St', 'C5Hc', '2K']
# 5
# value: 2K 2
# prevalue ['Wol', '6St/Fs', 'C5Hc', '2K']
# 1
# value: 2K 2
# prevalue ['Lei', '6GF', 'C53yHc', '2K']
# value: 2K 2
# prevalue ['Nmk', '6GF', 'C53yHc', '2K']
# value: 2K 2
# prevalue ['Mus', '7GF', 'C53yHc', '3K']
# value: 3K 3
# prevalue ['Rip', '8Sft', 'C33yHc', '6K']
# 24
# value: 6K 6
# prevalue ['Wol', '7St', 'C42yHc', '4K']
# value: 4K 4
# prevalue ['Wol', '6St', 'C52yMd', '2K']
# sh
# value: 2K 2
# prevalue ['Cur', '6Gd', '2y', '10K']
# 12
# value: 10K 10
# prevalue ['Sli', '7Gd', '2y', '6K']
# 21
# value: 6K 6
# For Shia And Lula is my name
# (<Element a at 0x2b15ad0>, 'href', 'http://www.racingpost.com/horses/owner_home.sd?owner_id=193113', 0)
# (<Element img at 0x2b15dd0>, 'src', 'http://images.racingpost.com/png_silks/3/1/1/193113.png', 0)
# (<Element a at 0x2b15ad0>, 'href', 'http://www.racingpost.com/horses/horse_home.sd?race_id=581305&r_date=2013-06-06&horse_id=783445', 0) http://www.racingpost.com/horses/horse_home.sd?race_id=581305&r_date=2013-06-06&horse_id=783445
# prevalue
#  ['Cat', '7GS', 'C6Md', '2K']
# value: 2K 2
# prevalue ['Ncs', '7GF', 'C6Hc', '1K']
# 18
# value: 1K 1
# prevalue ['Ncs', '8GS', 'C5Md', '2K']
# 43
# value: 2K 2
# prevalue ['Sth', '8St', 'C6Hc', '2K']
# 47
# value: 2K 2
# prevalue ['Ncs', '7Gd', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Ncs', '7Gd', 'C53yHc', '3K']
# 1
# value: 3K 3
# prevalue ['Don', '6GF', 'C5Hc', '2K']
# value: 2K 2
# prevalue ['Pon', '6Sft', 'C53yHc', '2K']
# 33
# value: 2K 2
# prevalue ['Pon', '6GF', 'C53yMd', '2K']
# 3
# value: 2K 2
# prevalue ['Red', '7Gd', 'C5Md', '2K']
# 6
# value: 2K 2
# prevalue ['Red', '6Sft', 'C5Md', '2K']
# value: 2K 2
# Dolly Diva is my name
# (<Element a at 0x2b15ad0>, 'href', 'http://www.racingpost.com/horses/owner_home.sd?owner_id=166831', 0)
# (<Element img at 0x2b15a10>, 'src', 'http://images.racingpost.com/png_silks/1/3/8/166831.png', 0)
# (<Element a at 0x2b15ad0>, 'href', 'http://www.racingpost.com/horses/horse_home.sd?race_id=581305&r_date=2013-06-06&horse_id=762233', 0) http://www.racingpost.com/horses/horse_home.sd?race_id=581305&r_date=2013-06-06&horse_id=762233
# prevalue
#  ['Hex', '17GF', 'C43yH', '2K']
# Danc
# value: 2K 2
# position PU
# prevalue ['Bev', '7GF', 'C63yHc', '1K']
# 18
# value: 1K 1
# prevalue ['Red', '8Fm', 'C53yHc', '3K']
# 18
# value: 3K 3
# prevalue ['Red', '8Gd', 'C62yMd', '1K']
# 13
# value: 1K 1
# prevalue ['Hay', '8Sft', 'C52yMd', '3K']
# 44
# value: 3K 3
# prevalue ['Wol', '7St', 'C52yMdAc', '2K']
# value: 2K 2
# Inca Chief is my name
# (<Element a at 0x2b15ad0>, 'href', 'http://www.racingpost.com/horses/owner_home.sd?owner_id=37296', 0)
# (<Element img at 0x2b29230>, 'src', 'http://images.racingpost.com/png_silks/6/9/2/37296.png', 0)
# (<Element a at 0x2b15ad0>, 'href', 'http://www.racingpost.com/horses/horse_home.sd?race_id=581305&r_date=2013-06-06&horse_id=685115', 0) http://www.racingpost.com/horses/horse_home.sd?race_id=581305&r_date=2013-06-06&horse_id=685115
# prevalue
#  ['Kem', '7St', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Mus', '7GS', 'C6Hc', '2K']
# 22
# value: 2K 2
# prevalue ['Wol', '7St', 'C6Hc', '1K']
# 15
# value: 1K 1
# prevalue ['Ncs', '7GS', 'C6Hc', '1K']
# 20
# value: 1K 1
# prevalue ['Wol', '7St', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Wol', '7St', 'C6Hc', '1K']
# 39
# value: 1K 1
# prevalue ['Wol', '7St/Slw', 'C6Hc', '1K']
# 10
# value: 1K 1
# prevalue ['Wol', '7St', 'C6Hc', '2K']
# value: 2K 2
# prevalue ['Wol', '7St', 'C7Hc', '1K']
# value: 1K 1
# prevalue ['Wol', '7St/Fs', 'C7Hc', '1K']
# value: 1K 1
# prevalue ['Wol', '9St', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Wol', '9St', 'C6Hc', '2K']
# 18
# value: 2K 2
# prevalue ['Thi', '7GF', 'C5Hc', '3K']
# value: 3K 3
# prevalue ['Ayr', '7Sft', 'C5Hc', '2K']
# 3
# value: 2K 2
# prevalue ['Wol', '7St', 'C6Hc', '1K']
# 34
# value: 1K 1
# prevalue ['Thi', '7GS', 'C5Hc', '2K']
# value: 2K 2
# prevalue ['Ncs', '7Sft', 'C5Hc', '2K']
# 11
# value: 2K 2
# prevalue ['Cat', '7GF', 'C5Hc', '3K']
# 27
# value: 3K 3
# prevalue ['Wol', '7St', 'C5Hc', '2K']
# value: 2K 2
# prevalue ['Cat', '7GS', 'C4Hc', '4K']
# 26
# value: 4K 4
# prevalue ['Wol', '7St', 'C5Hc', '1K']
# 21
# value: 1K 1
# prevalue ['Cat', '7Sft', 'C5Hc', '2K']
# 39
# value: 2K 2
# prevalue ['Wol', '7St/Fs', 'C5Hc', '2K']
# value: 2K 2
# prevalue ['Yor', '7Gd', 'C4Hc', '5K']
# value: 5K 5
# prevalue ['Thi', '7Hy', 'C4Hc', '4K']
# value: 4K 4
# prevalue ['Don', '7Gd', 'C5Hc', '2K']
# 3
# value: 2K 2
# prevalue ['Thi', '7Gd', 'C5Hc', '2K']
# value: 2K 2
# prevalue ['Ayr', '7GF', 'C6Hc', '2K']
# n
# value: 2K 2
# prevalue ['Ayr', '7GS', 'C5Hc', '4K']
# sh
# value: 4K 4
# prevalue ['Cat', '7GF', 'C6Hc', '1K']
# 25
# value: 1K 1
# prevalue ['Thi', '7Gd', 'C5Hc', '2K']
# value: 2K 2
# prevalue ['Cat', '7GF', 'C5Hc', '2K']
# value: 2K 2
# prevalue ['Lei', '7GF', 'C5Hc', '2K']
# 33
# value: 2K 2
# prevalue ['Thi', '7Gd', 'C6Hc', '2K']
# h
# value: 2K 2
# prevalue ['Wol', '7St', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Cat', '7GF', 'C6Hc', '1K']
# 12
# value: 1K 1
# prevalue ['Mus', '7GF', 'C5Hc', '3K']
# value: 3K 3
# prevalue ['Crl', '7Sft', 'C5Hc', '2K']
# value: 2K 2
# prevalue ['Ncs', '7GF', 'C5Hc', '2K']
# value: 2K 2
# prevalue ['Bev', '7GF', 'C5Hc', '4K']
# 9
# value: 4K 4
# prevalue ['Cat', '7GF', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Wol', '7St', 'C6Hc', '1K']
# 19
# value: 1K 1
# prevalue ['Wol', '7St', 'C6Hc', '1K']
# 22
# value: 1K 1
# prevalue ['Mus', '7GF', 'C5Hc', '3K']
# value: 3K 3
# prevalue ['Ncs', '7GF', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Kem', '7St', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Wol', '9St/Fs', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Wol', '7St', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Wol', '7St', 'C7Hc', '1K']
# h
# value: 1K 1
# prevalue ['Wol', '9St', 'C6Hc', '2K']
# 12
# value: 2K 2
# prevalue ['Sth', '7St', 'C6Hc', '2K']
# value: 2K 2
# prevalue ['Red', '6GF', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Wol', '7St', 'C6Hc', '2K']
# 20
# value: 2K 2
# prevalue ['Wol', '6St', 'C6Hc', '2K']
# value: 2K 2
# prevalue ['Wol', '7St', 'C5Hc', '3K']
# value: 3K 3
# prevalue ['Wol', '9St/Fs', 'C6Hc', '2K']
# 5
# value: 2K 2
# prevalue ['Wol', '6St', 'C6Hc', '2K']
# 15
# value: 2K 2
# prevalue ['Wol', '6St', 'C6Hc', '1K']
# 3
# value: 1K 1
# prevalue ['Sth', '7St', 'C5Hc', '2K']
# 16
# value: 2K 2
# prevalue ['Wol', '7St', 'C5Hc', '3K']
# 16
# value: 3K 3
# prevalue ['Wol', '7St', 'C4Hc', '5K']
# value: 5K 5
# prevalue ['Wol', '7St', 'C5Hc', '3K']
# 17
# value: 3K 3
# prevalue ['Red', '7Gd', 'C53yHc', '2K']
# value: 2K 2
# prevalue ['Mus', '7Sft', 'C6Hc', '2K']
# 12
# value: 2K 2
# prevalue ['Cat', '7Gd', 'C43yHc', '4K']
# 35
# value: 4K 4
# prevalue ['Thi', '8Sft', 'C53yHc', '4K']
# value: 4K 4
# prevalue ['Thi', '8Gd', 'C3Hc', '8K']
# 39
# value: 8K 8
# prevalue ['Don', '6GF', 'C43yHc', '4K']
# value: 4K 4
# prevalue ['Bev', '7GS', 'C33yHc', '6K']
# 12
# value: 6K 6
# prevalue ['Wol', '6St', 'C63yCl', '2K']
# value: 2K 2
# prevalue ['Kem', '7St', 'C63yCl', '2K']
# 1
# value: 2K 2
# prevalue ['Wol', '7St', 'C53yCl', '2K']
# value: 2K 2
# prevalue ['Kem', '7St', 'C63yCl', '2K']
# value: 2K 2
# prevalue ['Lin', '7St', 'C63yCl', '1K']
# n
# value: 1K 1
# prevalue ['Wol', '9St', 'C43yHc', '4K']
# 5
# value: 4K 4
# prevalue ['Lin', '8St', 'C43yHc', '4K']
# value: 4K 4
# prevalue ['Wol', '9St', 'C32y', '6K']
# value: 6K 6
# prevalue ['Lin', '6St', 'C42yNv', '3K']
# value: 3K 3
# prevalue ['Lin', '7St', 'C62yMdAc', '2K']
# value: 2K 2
# prevalue ['Lin', '6St', 'C62yMdAc', '2K']
# value: 2K 2
# prevalue ['Lin', '7St', 'C52yMd', '3K']
# value: 3K 3
# prevalue ['Nmk', '6Gd', 'C22yAc', '189K']
# value: 189K 189
# prevalue ['Thi', '7GF', 'C52yMdAc', '3K']
# value: 3K 3
# prevalue ['Lin', '8St', 'C52yMd', '3K']
# value: 3K 3
# prevalue ['Nmk', '7GF', 'C42yMd', '3K']
# value: 3K 3
# Dhhamaan is my name
# (<Element a at 0x2b290b0>, 'href', 'http://www.racingpost.com/horses/owner_home.sd?owner_id=170082', 0)
# (<Element img at 0x2b296b0>, 'src', 'http://images.racingpost.com/png_silks/2/8/0/170082.png', 0)
# (<Element a at 0x2b290b0>, 'href', 'http://www.racingpost.com/horses/horse_home.sd?race_id=581305&r_date=2013-06-06&horse_id=719542', 0) http://www.racingpost.com/horses/horse_home.sd?race_id=581305&r_date=2013-06-06&horse_id=719542
# prevalue
#  ['Mus', '5GF', 'C6Hc', '2K']
# value: 2K 2
# prevalue ['Wol', '5St', 'C6Hc', '2K']
# 8
# value: 2K 2
# prevalue ['Wol', '6St', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Lin', '5St', 'C6Hc', '2K']
# value: 2K 2
# prevalue ['Wol', '6St', 'C6Hc', '1K']
# 13
# value: 1K 1
# prevalue ['Wol', '5Sl', 'C5Hc', '2K']
# 7
# value: 2K 2
# prevalue ['Hay', '5Gd', 'C4Hc', '4K']
# 5
# value: 4K 4
# prevalue ['Mus', '5GS', 'C4Hc', '7K']
# value: 7K 7
# prevalue ['Mus', '5GF', 'C6Hc', '2K']
# 2
# value: 2K 2
# prevalue ['Wol', '6St', 'C5Hc', '2K']
# 8
# value: 2K 2
# prevalue ['Wol', '6St', 'C5Hc', '2K']
# value: 2K 2
# prevalue ['Wol', '5St', 'C5Hc', '2K']
# value: 2K 2
# prevalue ['Lin', '5St', 'C4Hc', '3K']
# 7
# value: 3K 3
# prevalue ['Lin', '5St', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Lin', '5St', 'C6Hc', '1K']
# 2
# value: 1K 1
# prevalue ['Wol', '5St', 'C6Hc', '1K']
# 7
# value: 1K 1
# prevalue ['Lin', '5St', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Wol', '5St', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Thi', '5GF', 'C5Hc', '3K']
# value: 3K 3
# prevalue ['Not', '5Gd', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Yar', '5GF', 'C6Hc', '2K']
# value: 2K 2
# prevalue ['Hay', '5GF', 'C5Hc', '2K']
# value: 2K 2
# prevalue ['Nby', '5GF', 'C5Hc', '3K']
# h
# value: 3K 3
# prevalue ['Wol', '5St', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Not', '5Fm', 'C6Hc', '2K']
# value: 2K 2
# prevalue ['Wol', '5St', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Sth', '5St', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Kem', '5St', 'C6Md', '2K']
# value: 2K 2
# prevalue ['Wol', '5St', 'C63yHc', '2K']
# value: 2K 2
# prevalue ['Wol', '5St', 'C63yHc', '2K']
# value: 2K 2
# prevalue ['Don', '5Sft', 'C53yHc', '3K']
# value: 3K 3
# prevalue ['Wol', '5St', 'C53yHc', '3K']
# value: 3K 3
# prevalue ['Lin', '5St', 'C63yHc', '2K']
# value: 2K 2
# prevalue ['Wol', '5St', 'C63yHc', '2K']
# 2
# value: 2K 2
# prevalue ['Sth', '5St', 'C63yHc', '2K']
# value: 2K 2
# prevalue ['Wol', '5St', 'C62yMdAc', '3K']
# value: 3K 3
# prevalue ['Sth', '5St', 'C62yMdAc', '2K']
# 16
# value: 2K 2
# prevalue ['Not', '5Hy', 'C52yMd', '2K']
# 27
# value: 2K 2
# before You´relikemefrank
# after You relikemefrank
# You relikemefrank is my name
# (<Element a at 0x2b29b30>, 'href', 'http://www.racingpost.com/horses/owner_home.sd?owner_id=89964', 0)
# (<Element img at 0x2b290b0>, 'src', 'http://images.racingpost.com/png_silks/b/4/6/89964b.png', 0)
# (<Element a at 0x2b29b30>, 'href', 'http://www.racingpost.com/horses/horse_home.sd?race_id=581305&r_date=2013-06-06&horse_id=787354', 0) http://www.racingpost.com/horses/horse_home.sd?race_id=581305&r_date=2013-06-06&horse_id=787354
# prevalue
#  ['War', '8GF', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Sth', '8St', 'C63yHc', '1K']
# value: 1K 1
# prevalue ['Wol', '7St/Fs', 'C6Hc', '1K']
# 20
# value: 1K 1
# prevalue ['Sth', '8St', 'C53yHc', '2K']
# 15
# value: 2K 2
# prevalue ['Thi', '7Gd', 'C53yHc', '3K']
# 12
# value: 3K 3
# prevalue ['Sth', '7St', 'C63yHc', '1K']
# value: 1K 1
# prevalue ['Bev', '7GF', 'C63yHc', '1K']
# value: 1K 1
# prevalue ['Chs', '8Gd', 'C53yHc', '4K']
# value: 4K 4
# prevalue ['Crl', '7GF', 'C63yHc', '1K']
# value: 1K 1
# prevalue ['Thi', '8Sft', 'C5Md', '2K']
# value: 2K 2
# prevalue ['Not', '6GF', 'C62yHc', '1K']
# value: 1K 1
# prevalue ['Ham', '6Sft', 'C52yHc', '2K']
# value: 2K 2
# prevalue ['Crl', '5Gd', 'C62yHc', '1K']
# 4
# value: 1K 1
# prevalue ['Ham', '5GF', 'C52yMdAc', '2K']
# 3
# value: 2K 2
# prevalue ['Hay', '6GF', 'C52yMd', '3K']
# 13
# value: 3K 3
# prevalue ['Crl', '6GS', 'C52yMdAc', '2K']
# value: 2K 2
# Jay Kay is my name
# (<Element a at 0x2b29bf0>, 'href', 'http://www.racingpost.com/horses/owner_home.sd?owner_id=194717', 0)
# (<Element img at 0x2b29f50>, 'src', 'http://images.racingpost.com/png_silks/7/1/7/194717.png', 0)
# (<Element a at 0x2b29bf0>, 'href', 'http://www.racingpost.com/horses/horse_home.sd?race_id=581305&r_date=2013-06-06&horse_id=814825', 0) http://www.racingpost.com/horses/horse_home.sd?race_id=581305&r_date=2013-06-06&horse_id=814825
# prevalue
#  ['Mus', '8GF', 'C6Hc', '2K']
# value: 2K 2
# prevalue ['Wol', '7St/Fs', 'C7Hc', '1K']
# value: 1K 1
# prevalue ['Kem', '6St', 'C5Md', '2K']
# value: 2K 2
# prevalue ['Red', '7Hy', 'C53yHc', '2K']
# 22
# value: 2K 2
# prevalue ['Red', '6Hy', 'C6Hc', '1K']
# 19
# value: 1K 1
# prevalue ['Wol', '6St', 'C6', '1K']
# value: 1K 1
# prevalue ['Crl', '8Hy', 'C53yHc', '2K']
# 31
# value: 2K 2
# prevalue ['Ncs', '7Gd', 'C53yHc', '3K']
# value: 3K 3
# prevalue ['Ayr', '5Gd', 'C43yHc', '4K']
# value: 4K 4
# prevalue ['Sth', '5St', 'C53yMd', '2K']
# value: 2K 2
# prevalue ['Don', '6Gd', 'C5Md', '2K']
# value: 2K 2
# prevalue ['Red', '6Sft', 'C5Md', '1K']
# value: 1K 1
# Artillery Train is my name
# (<Element a at 0x2b156b0>, 'href', 'http://www.racingpost.com/horses/owner_home.sd?owner_id=87355', 0)
# (<Element img at 0x2b153b0>, 'src', 'http://images.racingpost.com/png_silks/b/5/5/87355b.png', 0)
# (<Element a at 0x2b156b0>, 'href', 'http://www.racingpost.com/horses/horse_home.sd?race_id=581305&r_date=2013-06-06&horse_id=766660', 0) http://www.racingpost.com/horses/horse_home.sd?race_id=581305&r_date=2013-06-06&horse_id=766660
# prevalue
#  ['Red', '6GF', 'C6MdHc', '1K']
# value: 1K 1
# prevalue ['Red', '6Hy', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Cat', '12Sft', 'C6Hc', '2K']
# 33
# value: 2K 2
# prevalue ['Red', '6GF', 'C6MdHc', '1K']
# 15
# value: 1K 1
# prevalue ['Red', '7Gd', 'C5Md', '2K']
# 18
# value: 2K 2
# prevalue ['Ncs', '8GF', 'C63yHc', '1K']
# 28
# value: 1K 1
# prevalue ['Red', '7Gd', 'C62yCl', '1K']
# 33
# value: 1K 1
# prevalue ['Red', '7GS', 'C42yMd', '4K']
# 32
# value: 4K 4
# prevalue ['Ayr', '7Gd', 'C42yMd', '4K']
# 12
# value: 4K 4
# Zoom In is my name
# (<Element a at 0x2b29a10>, 'href', 'http://www.racingpost.com/horses/owner_home.sd?owner_id=205347', 0)
# (<Element img at 0x2b156b0>, 'src', 'http://images.racingpost.com/png_silks/7/4/3/205347.png', 0)
# (<Element a at 0x2b29a10>, 'href', 'http://www.racingpost.com/horses/horse_home.sd?race_id=581305&r_date=2013-06-06&horse_id=633993', 0) http://www.racingpost.com/horses/horse_home.sd?race_id=581305&r_date=2013-06-06&horse_id=633993
# prevalue
#  ['Red', '5GF', 'C6Sl', '2K']
# value: 2K 2
# prevalue ['Cat', '5Sft', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Cat', '5Sft', 'C6Hc', '2K']
# 12
# value: 2K 2
# prevalue ['Cat', '5GF', 'C6Hc', '2K']
# value: 2K 2
# prevalue ['Crl', '5GF', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Cat', '5GF', 'C6Hc', '1K']
# 10
# value: 1K 1
# prevalue ['Mus', '5GS', 'C6Hc', '2K']
# 20
# value: 2K 2
# prevalue ['Mus', '5Gd', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Cat', '5GF', 'C6Hc', '1K']
# h
# value: 1K 1
# prevalue ['Crl', '5Gd', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Bri', '5GF', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Wol', '5St', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Not', '5GF', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Lin', '5St', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Wol', '5St', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Lin', '5St', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Wol', '5St', 'C6Hc', '1K']
# 4
# value: 1K 1
# prevalue ['Lin', '5St', 'C6Hc', '1K']
# 7
# value: 1K 1
# prevalue ['Wol', '5St', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Wol', '5St', 'C6Sl', '1K']
# h
# value: 1K 1
# prevalue ['Wol', '5St', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Wol', '5St', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Wol', '5St', 'C6Hc', '2K']
# 2
# value: 2K 2
# prevalue ['Wol', '5St', 'C7Hc', '1K']
# value: 1K 1
# prevalue ['Wol', '5St', 'C7Hc', '1K']
# value: 1K 1
# prevalue ['Lin', '5St', 'C6Hc', '2K']
# 9
# value: 2K 2
# prevalue ['Lin', '5St', 'C6Hc', '2K']
# value: 2K 2
# prevalue ['Wol', '5St', 'C6Hc', '2K']
# value: 2K 2
# prevalue ['Bat', '5Fm', 'C6Cl', '2K']
# value: 2K 2
# prevalue ['War', '5Gd', 'C6Sl', '1K']
# value: 1K 1
# prevalue ['Wol', '5St', 'C6Hc', '2K']
# value: 2K 2
# prevalue ['Lin', '5St', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Wol', '5St/Fs', 'C6Hc', '2K']
# Fizzlephu
# value: 2K 2
# position 4d
# prevalue ['Lin', '5St', 'C6Hc', '1K']
# value: 1K 1
# prevalue ['Wol', '5St', 'C6Hc', '2K']
# value: 2K 2
# prevalue ['Lin', '5St', 'C6Hc', '1K']
# 4
# value: 1K 1
# prevalue ['Lin', '5St', 'C6Hc', '2K']
# value: 2K 2
# prevalue ['Wol', '5St', 'C5Hc', '3K']
# value: 3K 3
# prevalue ['Grl', '5St', 'C6Hc', '2K']
# 12
# value: 2K 2
# prevalue ['Wol', '5St/Fs', 'C6Hc', '2K']
# value: 2K 2
# prevalue ['Lin', '5St', 'C6Hc', '2K']
# value: 2K 2
# prevalue ['Lin', '5St', 'C5Hc', '2K']
# value: 2K 2
# prevalue ['Wol', '5St', 'C6Hc', '2K']
# 9
# value: 2K 2
# prevalue ['Wol', '5St', 'C5Hc', '2K']
# 9
# value: 2K 2
# prevalue ['Wol', '5St', 'C6Hc', '2K']
# value: 2K 2
# prevalue ['Wol', '5St', 'C6Hc', '2K']
# value: 2K 2
# prevalue ['Wol', '5St', 'C6Hc', '2K']
# value: 2K 2
# prevalue ['Wol', '5St', 'C6Hc', '1K']
# h
# value: 1K 1
# prevalue ['Kem', '5St', 'C6Hc', '2K']
# 9
# value: 2K 2
# prevalue ['Wol', '5St', 'C6Hc', '2K']
# 11
# value: 2K 2
# prevalue ['Kem', '5St', 'C6Hc', '2K']
# 1
# value: 2K 2
# prevalue ['Wol', '5St', 'C6Hc', '2K']
# value: 2K 2
# prevalue ['Wol', '5St', 'C6Hc', '2K']
# value: 2K 2
# prevalue ['Lin', '5St', 'C6Hc', '3K']
# 3
# value: 3K 3
# prevalue ['Bat', '6GF', 'C5Hc', '3K']
# value: 3K 3
# prevalue ['Not', '5GF', 'C6Hc', '2K']
# 13
# value: 2K 2
# prevalue ['War', '5GF', 'C5Hc', '3K']
# value: 3K 3
# prevalue ['Sth', '5St', 'C6Hc', '2K']
# 5
# value: 2K 2
# prevalue ['Wol', '5St', 'C6Hc', '2K']
# value: 2K 2
# prevalue ['Lin', '5St', 'C6Hc', '2K']
# value: 2K 2
# prevalue ['Wol', '5St', 'C5Hc', '3K']
# value: 3K 3
# prevalue ['Wol', '5St', 'C5Hc', '3K']
# 6
# value: 3K 3
# prevalue ['Kem', '5St', 'C6Hc', '2K']
# value: 2K 2
# prevalue ['Wol', '5St', 'C6Hc', '2K']
# value: 2K 2
# prevalue ['Lin', '5St', 'C5Hc', '3K']
# 8
# value: 3K 3
# prevalue ['Bev', '5GF', 'C5Hc', '5K']
# value: 5K 5
# prevalue ['Goo', '5Gd', 'C53yHc', '3K']
# value: 3K 3
# prevalue ['Nby', '6Gd', 'C43yHc', '6K']
# value: 6K 6
# prevalue ['Goo', '5GF', 'C33yHc', '9K']
# value: 9K 9
# prevalue ['Nmk', '5GF', 'C3Hc', '8K']
# 5
# value: 8K 8
# prevalue ['Yor', '5GF', 'C3Hc', '8K']
# value: 8K 8
# prevalue ['Not', '5Gd', 'C23yHc', '14K']
# 12
# value: 14K 14
# prevalue ['Chs', '5GF', 'C23yHc', '14K']
# value: 14K 14
# prevalue ['Mus', '5Gd', 'C32yHc', '11K']
# value: 11K 11
# prevalue ['Mus', '5Gd', 'C22yHc', '12K']
# 3
# value: 12K 12
# prevalue ['Rip', '5GF', 'C32y', '6K']
# value: 6K 6
# prevalue ['Yor', '5Gd', 'C12yL', '18K']
# value: 18K 18
# prevalue ['Nby', '5GF', 'C22y', '78K']
# value: 78K 78
# prevalue ['Yor', '5Gd', 'C32yHc', '8K']
# value: 8K 8
# prevalue ['Crl', '5GS', 'C52yNvAc', '3K']
# 8
# value: 3K 3
# prevalue ['Thi', '5GF', 'C52yMd', '5K']
# value: 5K 5
# prevalue ['Ncs', '5Gd', 'C52yNv', '3K']
# value: 3K 3
# prevalue ['Mus', '5GF', 'C52yMdAc', '3K']
# value: 3K 3
# Triskaidekaphobia is my name

# %%
try:
    print hs
except Exception, arg:
    print "exc", arg.args
# Out:
# [Crossley:
# 06Nov12 Red 7Hy C53yHc 2	4/12 2.5L Kuwait Star 9-6) 25.0	Barry McHugh	60/*/*
# 08Oct12 Pon 8GS C53yMd 2	6/11 21L A*Juba 9-3) 66.0	Tony Hamilton	63/*/*
# 02Jun12 Bev 7GF C53yHc 2	10/14 10L Annie Walker 9-2) 22.0	Dale Swift	66/*/*
# 12May12 Thi 8Sft C5Md 2	8/14 6.5L Exclusive Dancer 8-8) 8.0	Dale Swift	67/*/*
# 14Oct11 Red 8GS C62yMd 1	3/7 5.25L Willie Wag Tail 9-3) 7.0	Dale Swift	0/*/*
# 22Sep11 Pon 6GF C42yMd 4	5/10 12.5L Glamorous Angel 9-3) 25.0	Dale Swift	0/*/*
# 12Feb11 Lin 5St C4Hc 3	4/6 7L Breathless Kiss 9-2) p 1.875	Graham Gibbons	71/*/*
# 07Jan11 Lin 5St C6Hc 1	1/9 0.5L Estonia 9-4) p 2.75	Graham Gibbons	67/*/*
# 31Dec10 Lin 5St C6Hc 1	1/9 2L The Tatling 9-5) p 1.875	Graham Gibbons	61/*/*
# 13Dec10 Wol 5St C6Hc 1	5/11 7L Sharp Shoes 9-5) p 1.625	Luke Morris	61/*/*
# 05Dec10 Lin 5St C6Hc 1	1/7 1.25L Spic *n Span 9-7) p 2.25	Luke Morris	55/*/*
# 02Sep10 Wol 5St C6Hc 1	2/12 1.25L Towy Boy 8-12) p 3.5	Ashley Morgan	52/*/*
# 27Aug10 Thi 5GF C5Hc 3	2/10 1.5L Mayoman 9-7) p 10.0	Ashley Morgan	55/*/*
# 13Aug10 Not 5Gd C6Hc 1	4/11 3.25L Gracie*s Games 8-7) p 4.5	Andrew Elliott	55/*/*
# 20Jul10 Yar 5GF C6Hc 2	1/6 0.5L Pocket*s Pick 9-4) p 2.75	Andrew Elliott	52/*/*
# 02Jul10 Hay 5GF C5Hc 2	2/5 1.5L Angelo Poliziano 9-11) p 2.75	Francis Hayes	51/*/*
# 22Jun10 Nby 5GF C5Hc 3	1/8 1L Avrilo 10-0) p 16.0	Andrew Elliott	51/*/*
# 04Jun10 Wol 5St C6Hc 1	3/11 1.25L Mansii 9-1) p 7.5	Andrew Elliott	46/*/*
# 27Apr10 Not 5Fm C6Hc 2	5/14 2.75L Micky Mac 9-2) p 20.0	Tadhg O*Shea	46/*/*
# 10Apr10 Wol 5St C6Hc 1	7/13 4.75L Across The Sands 8-10) p 20.0	Liam Jones	48/*/*
# 11Mar10 Sth 5St C6Hc 1	7/9 8.25L Mr Funshine 8-11) p 20.0	Duran Fentiman	50/*/*
# 23Sep09 Kem 5St C6Md 2	3/7 3.5L Edith*s Boy 9-3) p 20.0	Ian Mongan	47/*/*
# 12Sep09 Wol 5St C63yHc 2	6/10 6.25L Rainy Night 9-1) b1 9.0	P J McDonald	48/*/*
# 17Aug09 Wol 5St C63yHc 2	2/10 1.5L First Blade 9-0) p 6.5	Jamie Kyne	47/*/*
# 01Aug09 Don 5Sft C53yHc 3	6/7 18.5L La Capriosa 9-2) p 11.0	Royston Ffrench	50/*/*
# 22Jun09 Wol 5St C53yHc 3	4/8 3.25L Angelo Poliziano 9-3) p 8.0	Jamie Kyne	49/*/*
# 28Jan09 Lin 5St C63yHc 2	3/7 1.75L Brown Lentic 8-0) p 10.0	Andrew Elliott	45/*/*
# 23Jan09 Wol 5St C63yHc 2	3/10 2L Kheley 9-6) p 33.0	Andrew Elliott	45/*/*
# 08Jan09 Sth 5St C63yHc 2	6/8 6.25L Halaak 8-12) p 50.0	Andrew Elliott	46/*/*
# 15Dec08 Wol 5St C62yMdAc 3	7/11 12.5L Saif Al Fahad 8-13) 33.0	Paul Mulrennan	0/*/*
# 26Jul12 Don 6GF C5Hc 2	15/17 14.5L Sleepy Blue Ocean 9-2) 50.0	Julie Burke	65/*/*
# 26May12 Chs 6GF C5Hc 4	8/10 38L Green Park 9-4) p 20.0	Graham Lee	70/*/*
# 19May12 Don 6Gd C4Hc 5	15/18 14L Italian Tom 9-0) 66.0	Royston Ffrench	74/*/*
# 27Apr12 Don 5Hy C4Hc 4	13/13 14.5L Long Awaited 9-5) 25.0	Royston Ffrench	75/*/*
# 21Dec11 Kem 8St C63yCl 1	4/4 13L Encore Un Fois 8-13) 3.0	Kieren Fallon	57/*/*
# 06Dec11 Sth 6St C6Cl 1	10/13 14.5L Global Village 8-7) 33.0	Paul McGiff	62/*/*
# 22Nov11 Sth 6St C6Hc 1	6/11 11L Take Cover 9-11) 9.0	Julie Burke	65/*/*
# 05Nov11 Don 7Sft C5Hc 2	2/15 2.75L Sam Nombulist 9-3) 16.0	Sam James	73/*/*
# 29Oct11 Wol 6St C5Hc 1	9/11 5.25L Frequency 9-7) 2.5	Amy Ryan	68/*/*
# 25Oct11 Cat 6Sft C53yHc 2	2/8 1.5L Rowan Spirit 9-0) 4.5	Julie Burke	73/*/*
# 18Sep11 Ham 6Sft C53yHc 2	6/8 10.5L Hills Of Dakota 9-4) 2.25	Julie Burke	73/*/*
# 08Sep11 Eps 6GS C53yHc 3	1/8 1L Blue Deer 8-9) 1.875	Julie Burke	68/*/*
# 26Aug11 Ham 6GS C63yHc 1	1/7 1.5L Inca Blue 9-0) 1.25	Julie Burke	63/*/*
# 18Aug11 Ham 6Gd C63yHc 1	1/6 2.25L Tahitian Princess 9-4) 2.125	Julie Burke	57/*/*
# 02Aug11 Cat 7Gd C63yHc 2	8/13 9.75L One Of Twins 8-3) 7.5	Phillip Makin	60/*/*
# 09Jul11 Ham 6Gd C6MdSl 2	4/10 2L Weetentherty 9-3) 1.4	P J McDonald	65/*/*
# 15Mar11 Sth 6St C53yMd 1	8/8 34L Twice Red 9-3) 33.0	Tom Eaves	0/*/*
# 24Feb11 Sth 5St C6Md 1	9/9 18L Take Your Partner 8-13) 5.0	Tom Eaves	0/*/*
# 26Oct10 Cat 6GS C62yMd 2	3/10 3.5L Magnini 9-3) 16.0	Barry McHugh	0/*/*

# %%
def byCourse(race, c = course):
    return c==race.course

hs[1].filt(byCourse, disp=True)
# Out:
# 'Deliberation: \n'

# %% [markdown]
# <div id="radio">
#   <input type="radio" id="radio1" name="radio"><label for="radio1">Choice 1</label>
#   <input type="radio" id="radio2" name="radio" checked="checked"><label for="radio2">Choice 2</label>
#   <input type="radio" id="radio3" name="radio"><label for="radio3">Choice 3</label>
# </div>
#
# <script>
#     $("#radio").buttonset();
#
#     $('#radio :radio').click(function() {
#         var kernel = IPython.notebook.kernel;
#         kernel.execute("print = "+$(this).attr('id')+"");
#     });
# </script>

# %%
def input(varname, prompt=''):
        """Prompt user for input and assign string val to given variable name."""
        js_code = ("""
        var value = prompt("{prompt}","");
        var py_code = "{varname} = " + value + "";
        IPython.notebook.kernel.execute(py_code);
        """).format(prompt=prompt, varname=varname)
        return IPython.core.display.Javascript(js_code)

# %%
uif = """ 
    function updateIframe(index){
        
        if (index < 0){
            index += horseLinks.length; 
        }
        
        counter = index;

        

        var url = horseLinks[index%horseLinks.length];

        
        document.getElementById("hfr").src = url;
        
        return false;
    }"""

fi = """
    var counter = 0;
    var index = 0;

    function findIndex(arr,obj) {
 	var ind = arr.indexOf(obj);
 	if (ind > -1){
		return ind;
	} else {
		return counter;
	}
    
}


alert(horseLinks);

"""

horseCarousel = """
    <table width="600px" border="2" id="horseCarouselTable">

    <tr>

    <td rowspan="2" id="horseCarouselNavigation">
    <img src="leftArrow.gif" onclick="updateIframe(counter+1); return false"/>
    <br />
    <a href="#" onclick="updateIframe(counter-1); return false"><img src="rightArrow.gif"/></a>
    </td>
    <td>Horse Form / Race Name</td>

    <td>H2H Horses</td>
    </tr>

    <tr>

    <td id= "horseCarouselInformation">Race name to appear here</td>

    <td id= "horseCarouselH2H">Other horses from both races here</td>
    </tr>

    </table>

    <br />
"""

print type(horseCarousel)
# Out:
# <type 'str'>

# %%
from IPython.display import Javascript
import IPython



class HorseFrame(Javascript):
    
    def title(name, text = ""):
        return "<title> " + str(name) + " " + str(text) + " </title> "
    def head():
        return "<head> " + self.title + "</head> "
    
    def scripts(self,scripts,horse, list = None):
        start = "<script type='text/javascript'>\n" + horse.horseLinks(list) + "\n"
        for script in scripts:
            start = start + "\t\t" + script + "\n"
        
        end = "</script>"
        
        return start + end
         
    def __init__(self, horse , width=800, height=600, filter = None):
        
        self.width = width
        self.height = height
        self.horse = horse
        self.title = "<title> " + str(self.horse.name) + " </title> "
        l = []
        #print "list before", l
        #print filter is None, "fcheck"
        if filter is None:
            l = self.horse.races
        else:
            print "filter"+ str(filter)
            l = l + self.horse.filt(filter)
            
            
        #print "after", l
        self.scripts = self.scripts([fi,uif],horse, l)
        
        self.head = "<head> " + self.title + "\n" + self.scripts + "</head> "
        
        #print self.head
        
        
        
        #print type(self.title), type(self.head)
        
        
    

    def __repr__(self):
        
        for f in (self.head,horseCarousel,self.width, self.height,self.horse.href):
            print type(f)
        r = """
        <html>
               # %s

            <body>
                # %s
            
                <iframe
                    width="%i"
                    height="%i"
                    src="%s"
                    frameborder="0"
                    id = "hfr"
                ></iframe>
            </body>
        </html>
        
        """%(self.head,horseCarousel,self.width, self.height,self.horse.href)
        
        #print r
        
        return r
    
#start=int(timedelta(hours=1, minutes=46, seconds=40).total_seconds())

#filtered = hs[1].filt(byCourse)
hf = HorseFrame(hs[1],filter =byCourse)
#IPython.display.display(hf)

from IPython.display import display_html 


#help(hf)
# Out:
# filter<function byCourse at 0x2b1d6e0>
# hlinks []

# %%
display_html(hf) 
#display_html(hf, raw=True)
# Out:
# <type 'str'>
# <type 'str'>
# <type 'int'>
# <type 'int'>
# <type 'str'>
#         <html>
#                <head> <title> Deliberation </title>
# <script type='text/javascript'>
# var horseLinks = ['http://www.racingpost.com/horses/horse_home.sd?horse_id=769578']
#
#     var counter = 0;
#     var index = 0;
#
#     function findIndex(arr,obj) {
#  	var ind = arr.indexOf(obj);
#  	if (ind > -1){
# 		return ind;
# 	} else {
# 		return counter;
# 	}
#
# }
#
#
# alert(horseLinks);
#
#
#
#     function updateIframe(index){
#
#         if (index < 0){
#             index += horseLinks.length;
#         }
#
#         counter = index;
#
#
#
#         var url = horseLinks[index%horseLinks.length];
#
#
#         document.getElementById("hfr").src = url;
#
#         return false;
#     }
# </script></head>
#
#             <body>
#
#     <table width="600px" border="2" id="horseCarouselTable">
#
#     <tr>
#
#     <td rowspan="2" id="horseCarouselNavigation">
#     <img src="leftArrow.gif" onclick="updateIframe(counter+1); return false"/>
#     <br />
#     <a href="#" onclick="updateIframe(counter-1); return false"><img src="rightArrow.gif"/></a>
#     </td>
#     <td>Horse Form / Race Name</td>
#
#     <td>H2H Horses</td>
#     </tr>
#
#     <tr>
#
#     <td id= "horseCarouselInformation">Race name to appear here</td>
#
#     <td id= "horseCarouselH2H">Other horses from both races here</td>
#     </tr>
#
#     </table>
#
#     <br />
#
#
#                 <iframe
#                     width="800"
#                     height="600"
#                     src="http://www.racingpost.com/horses/horse_home.sd?horse_id=769578"
#                     frameborder="0"
#                     id = "hfr"
#                 ></iframe>
#             </body>
#         </html>

# %%
import itertools

filters = [byCourse]
res = list(itertools.product(hs, filters))
print str(res)
# Out:
# [(Crossley:
# 06Nov12 Red 7Hy C53yHc 2	4/12 2.5L Kuwait Star 9-6) 25.0	Barry McHugh	60/*/*
# 08Oct12 Pon 8GS C53yMd 2	6/11 21L A*Juba 9-3) 66.0	Tony Hamilton	63/*/*
# 02Jun12 Bev 7GF C53yHc 2	10/14 10L Annie Walker 9-2) 22.0	Dale Swift	66/*/*
# 12May12 Thi 8Sft C5Md 2	8/14 6.5L Exclusive Dancer 8-8) 8.0	Dale Swift	67/*/*
# 14Oct11 Red 8GS C62yMd 1	3/7 5.25L Willie Wag Tail 9-3) 7.0	Dale Swift	0/*/*
# 22Sep11 Pon 6GF C42yMd 4	5/10 12.5L Glamorous Angel 9-3) 25.0	Dale Swift	0/*/*
# 17Jul11 Red 7GF C52yMd 2	8/12 13L Asatir 9-3) 80.0	Phillip Makin	0/*/*, <function byCourse at 0x2b1d6e0>), (Deliberation:
# 26Jul12 Don 6GF C5Hc 2	15/17 14.5L Sleepy Blue Ocean 9-2) 50.0	Julie Burke	65/*/*
# 26May12 Chs 6GF C5Hc 4	8/10 38L Green Park 9-4) p 20.0	Graham Lee	70/*/*
# 19May12 Don 6Gd C4Hc 5	15/18 14L Italian Tom 9-0) 66.0	Royston Ffrench	74/*/*
# 27Apr12 Don 5Hy C4Hc 4	13/13 14.5L Long Awaited 9-5) 25.0	Royston Ffrench	75/*/*
# 21Dec11 Kem 8St C63yCl 1	4/4 13L Encore Un Fois 8-13) 3.0	Kieren Fallon	57/*/*
# 06Dec11 Sth 6St C6Cl 1	10/13 14.5L Global Village 8-7) 33.0	Paul McGiff	62/*/*
# 22Nov11 Sth 6St C6Hc 1	6/11 11L Take Cover 9-11) 9.0	Julie Burke	65/*/*
# 02Sep10 Wol 5St C6Hc 1	2/12 1.25L Towy Boy 8-12) p 3.5	Ashley Morgan	52/*/*
# 27Aug10 Thi 5GF C5Hc 3	2/10 1.5L Mayoman 9-7) p 10.0	Ashley Morgan	55/*/*
# 13Aug10 Not 5Gd C6Hc 1	4/11 3.25L Gracie*s Games 8-7) p 4.5	Andrew Elliott	55/*/*
# 20Jul10 Yar 5GF C6Hc 2	1/6 0.5L Pocket*s Pick 9-4) p 2.75	Andrew Elliott	52/*/*
# 02Jul10 Hay 5GF C5Hc 2	2/5 1.5L Angelo Poliziano 9-11) p 2.75	Francis Hayes	51/*/*
# 22Jun10 Nby 5GF C5Hc 3	1/8 1L Avrilo 10-0) p 16.0	Andrew Elliott	51/*/*
# 04Jun10 Wol 5St C6Hc 1	3/11 1.25L Mansii 9-1) p 7.5	Andrew Elliott	46/*/*
# 27Apr10 Not 5Fm C6Hc 2	5/14 2.75L Micky Mac 9-2) p 20.0	Tadhg O*Shea	46/*/*
# 10Apr10 Wol 5St C6Hc 1	7/13 4.75L Across The Sands 8-10) p 20.0	Liam Jones	48/*/*
# 11Mar10 Sth 5St C6Hc 1	7/9 8.25L Mr Funshine 8-11) p 20.0	Duran Fentiman	50/*/*
# 23Sep09 Kem 5St C6Md 2	3/7 3.5L Edith*s Boy 9-3) p 20.0	Ian Mongan	47/*/*
# 12Sep09 Wol 5St C63yHc 2	6/10 6.25L Rainy Night 9-1) b1 9.0	P J McDonald	48/*/*
# 17Aug09 Wol 5St C63yHc 2	2/10 1.5L First Blade 9-0) p 6.5	Jamie Kyne	47/*/*
# 01Aug09 Don 5Sft C53yHc 3	6/7 18.5L La Capriosa 9-2) p 11.0	Royston Ffrench	50/*/*
# 22Jun09 Wol 5St C53yHc 3	4/8 3.25L Angelo Poliziano 9-3) p 8.0	Jamie Kyne	49/*/*
# 28Jan09 Lin 5St C63yHc 2	3/7 1.75L Brown Lentic 8-0) p 10.0	Andrew Elliott	45/*/*
# 23Jan09 Wol 5St C63yHc 2	3/10 2L Kheley 9-6) p 33.0	Andrew Elliott	45/*/*
# 08Jan09 Sth 5St C63yHc 2	6/8 6.25L Halaak 8-12) p 50.0	Andrew Elliott	46/*/*
# 15Dec08 Wol 5St C62yMdAc 3	7/11 12.5L Saif Al Fahad 8-13) 33.0	Paul Mulrennan	0/*/*
# 12Nov08 Sth 5St C62yMdAc 2	7/8 16L Silent Wonder 8-9) 40.0	Russ Kennemore	0/*/*
# 29Oct08 Not 5Hy C52yMd 2	8/8 27L Affluent 8-12) 40.0	David Allan	0/*/*, <function byCourse at 0x2b1d6e0>), (Jay Kay:
# 06May13 War 8GF C6Hc 1	10/12 11.5L Evergreen Forest 9-0) 50.0	Ian Burns	51/*/*
# 04Oct12 Sth 8St C63yHc 1	8/9 16.5L Twin Shadow 8-13) 16.0	Chris Catlin	54/*/*
# 14Sep12 Wol 7St/Fs C6Hc 1	9/10 20L Light Burst 9-6) 22.0	Chris Catlin	55/*/*
# 28Aug12 Sth 8St C53yHc 2	7/11 15L Dubai Sunshine 9-7) 16.0	Neil Farley	56/*/*
# 16Dec06 Lin 5St C5Hc 3	9/9 8L Stoneacre Boy 8-13) 33.0	Paul Fitzsimons	63/*/*
# 13Sep06 Bev 5GF C5Hc 5	10/13 7.5L Sir Nod 9-5) 20.0	Adrian Nicholls	68/*/*
# 09Sep06 Goo 5Gd C53yHc 3	7/8 8.25L Safari Mischief 8-11) 16.0	Paul Fitzsimons	68/*/*
# 18Aug06 Nby 6Gd C43yHc 6	11/13 10.5L Stanley Goodspeed 9-2) 28.0	Paul Fitzsimons	72/*/*
# 04Aug06 Goo 5GF C33yHc 9	11/12 6.25L Terentia 9-6) 33.0	Paul Fitzsimons	75/*/*
# 22Jul06 Nmk 5GF C3Hc 8	8/9 5L Pic Up Sticks 9-2) 22.0	Paul Fitzsimons	79/*/*
# 14Jul06 Yor 5GF C3Hc 8	5/6 6.5L Malapropism 9-10) 8.0	Paul Fitzsimons	83/*/*
# 01Jun06 Not 5Gd C23yHc 14	9/9 12L Glenviews Youngone 8-4) b1 33.0	Paul Fitzsimons	87/*/*
# 11May06 Chs 5GF C23yHc 14	9/12 6.5L Empress Jain 9-4) 8.5	Paul Fitzsimons	90/*/*
# 16Oct05 Mus 5Gd C32yHc 11	1/10 0.5L Blazing Heights 8-4) 9.0	Royston Ffrench	87/*/*
# 12Sep05 Mus 5Gd C22yHc 12	5/12 3L Come Out Fighting 9-2) 8.0	Joe Fanning	89/*/*
# 30Aug05 Rip 5GF C32y 6	4/8 5.5L Playful 8-9) 8.0	Darren Williams	93/*/*
# 17Aug05 Yor 5Gd C12yL 18	7/10 5.5L Tabaret 8-11) v1 9.0	Darren Williams	95/*/*
# 16Jul05 Nby 5GF C22y 78	16/25 6.75L Lady Livius 8-5) 6.0	Darren Williams	0/*/*
# 09Jul05 Yor 5Gd C32yHc 8	1/9 3.5L Curtail 9-3) 14.0	Darren Williams	84/*/*
# 14Jun05 Crl 5GS C52yNvAc 3	6/8 8L Indigo Nights 8-4) 3.5	Darren Williams	0/*/*
# 03Jun05 Thi 5GF C52yMd 5	1/13 0.5L Royal Power 9-0) 3.5	Darren Williams	0/*/*
# 19May05 Ncs 5Gd C52yNv 3	5/7 3.25L Mullaad 8-12) 33.0	Darren Williams	0/*/*
# 12Apr05 Mus 5GF C52yMdAc 3	5/9 4.25L Lake Hero 8-4) 12.0	Darren Williams	0/*/*, <function byCourse at 0x2b1d6e0>)]

# %%
options = ""

for h in hs:
    options = options + "<option value=" + "".join(h.name.split()) + ">" + h.name + "</option>\n"

dropdown = """
<select id ="horses" onchange="changeHorse()">
# %s
</select>"""  % options
print dropdown
# Out:
# <select id ="horses" onchange="changeHorse()">
# <option value=Crossley>Crossley</option>
# <option value=Deliberation>Deliberation</option>
# <option value=CrossTheBoss>Cross The Boss</option>
# <option value=ForShiaAndLula>For Shia And Lula</option>
# <option value=DollyDiva>Dolly Diva</option>
# <option value=IncaChief>Inca Chief</option>
# <option value=Dhhamaan>Dhhamaan</option>
# <option value=Yourelikemefrank>You relikemefrank</option>
# <option value=JayKay>Jay Kay</option>
# <option value=ArtilleryTrain>Artillery Train</option>
# <option value=ZoomIn>Zoom In</option>
# <option value=Triskaidekaphobia>Triskaidekaphobia</option>
#
# </select>

# %%
import json,copy


#help(hs[0])
horse = hs[3]

def getStory(horse):
    #print "horse", type(horse)
    s = horse.__dict__["races"]
    r = copy.deepcopy(s)
    #print "r[races]", type(r)
    races = horse.races
    dict = horse.__dict__
    dict['races'] = ""
    name = "".join(horse.name.split())
                   
    print name
    
    #print "t[0]", type(races[0]), races[0]
    #print type(r['races'])
    
    #json_races = [race.__dict__ for race in races]
    #r['races'] = ""
     
    data_string = json.dumps(dict)
    
    raceArrayString = " var races = [];"
    for r in races:
        raceArrayString = raceArrayString + "\n\tvar string = '"+json.dumps(r.__dict__)+"';"
        raceArrayString = raceArrayString + "\n\tvar raceobj = JSON.parse(string);"
        raceArrayString = raceArrayString + "\n\traces.push(raceobj);"
    raceArrayString = raceArrayString + "\n %s['races'] = races;" %name
    raceArrayString = raceArrayString + "\n allHorses['%s'] = %s;" % (horse.name, name)
    
    #we need to construct json
    
    #print data_string
    #
    start = "<script type='text/javascript'>;\n var jsonString = '" + data_string + "';"
    
    middle = """
        var %s = JSON.parse(jsonString);
        
    """ % name
    preend = """
    
    """
    end = "</script>"
   
    story = start+middle+raceArrayString +preend+end
    return story
    
print getStory(hs[4])
# Out:
# DollyDiva
# <script type='text/javascript'>;
#  var jsonString = '{"races": "", "href": "http://www.racingpost.com/horses/horse_home.sd?horse_id=783445", "name": "Dolly Diva"}';
#         var DollyDiva = JSON.parse(jsonString);
#
#      var races = [];
# 	var string = '{"going": "GS", "distNext": "8.75L Running Reef 9-11)", "jockey": "Micky Fenton", "weight": 137, "rpr": "*", "raceClass": "C6Md", "price": 80.0, "pos": 8, "value": 2, "ts": "*", "course": "Cat", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=578155", "date": "24May13", "furlongs": 7, "OR": 58, "runners": 12}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "GF", "distNext": "18L Never Forever 9-4)", "jockey": "Lee Topliss", "weight": 128, "rpr": "*", "raceClass": "C6Hc", "price": 28.0, "pos": 10, "value": 1, "ts": "*", "course": "Ncs", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=576941", "date": "08May13", "furlongs": 7, "OR": 60, "runners": 10}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "GS", "distNext": "43L Lady Artiste 8-12)", "jockey": "P J McDonald", "weight": 139, "rpr": "*", "raceClass": "C5Md", "price": 10.0, "pos": 7, "value": 2, "ts": "*", "course": "Ncs", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=574358", "date": "06Apr13", "furlongs": 8, "OR": 60, "runners": 8}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "St", "distNext": "47L Royal Holiday 9-6)", "jockey": "Russ Kennemore", "weight": 128, "rpr": "*", "raceClass": "C6Hc", "price": 20.0, "pos": 8, "value": 2, "ts": "*", "course": "Sth", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=573822", "date": "26Mar13", "furlongs": 8, "OR": 60, "runners": 8}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "Gd", "distNext": "3.25L Cross The Boss 9-0)", "jockey": "Micky Fenton", "weight": 132, "rpr": "*", "raceClass": "C6Hc", "price": 25.0, "pos": 4, "value": 1, "ts": "*", "course": "Ncs", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=563801", "date": "10Sep12", "furlongs": 7, "OR": 60, "runners": 15}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "Gd", "distNext": "1L Lolita Lebron 9-0)", "jockey": "P J McDonald", "weight": 118, "rpr": "*", "raceClass": "C53yHc", "price": 20.0, "pos": 2, "value": 3, "ts": "*", "course": "Ncs", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=561320", "date": "24Aug12", "furlongs": 7, "OR": 60, "runners": 8}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "GF", "distNext": "8.75L Willbeme 9-3)", "jockey": "Micky Fenton", "weight": 126, "rpr": "*", "raceClass": "C5Hc", "price": 28.0, "pos": 11, "value": 2, "ts": "*", "course": "Don", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=560099", "date": "04Aug12", "furlongs": 6, "OR": 62, "runners": 14}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "Sft", "distNext": "33L Byronic Hero 9-5)", "jockey": "Micky Fenton", "weight": 123, "rpr": "*", "raceClass": "C53yHc", "price": 12.0, "pos": 8, "value": 2, "ts": "*", "course": "Pon", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=556976", "date": "24Jun12", "furlongs": 6, "OR": 64, "runners": 8}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "GF", "distNext": "3L Shena*s Dream 8-12)", "jockey": "Micky Fenton", "weight": 124, "rpr": "*", "raceClass": "C53yMd", "price": 7.0, "pos": 3, "value": 2, "ts": "*", "course": "Pon", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=555092", "date": "01Jun12", "furlongs": 6, "OR": 0, "runners": 7}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "Gd", "distNext": "6L Liliargh 9-0)", "jockey": "Micky Fenton", "weight": 126, "rpr": "*", "raceClass": "C5Md", "price": 33.0, "pos": 4, "value": 2, "ts": "*", "course": "Red", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=554294", "date": "21May12", "furlongs": 7, "OR": 0, "runners": 15}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "Sft", "distNext": "9.5L Isola Verde 8-12)", "jockey": "Micky Fenton", "weight": 124, "rpr": "*", "raceClass": "C5Md", "price": 20.0, "pos": 6, "value": 2, "ts": "*", "course": "Red", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=553674", "date": "14May12", "furlongs": 6, "OR": 0, "runners": 8}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
#  DollyDiva['races'] = races;
#  allHorses['Dolly Diva'] = DollyDiva;
#
#     </script>

# %%
from horsetemplate import *

l ="\n".join([getStory(h) for h in hs])

output = head + l + dropdown + body
# Out:
# Crossley
# Deliberation
# CrossTheBoss
# ForShiaAndLula
# DollyDiva
# IncaChief
# Dhhamaan
# Yourelikemefrank
# JayKay
# ArtilleryTrain
# ZoomIn
# Triskaidekaphobia

# %%
display_html(output, raw=True)

# %%
print output
# Out:
# <html>
#     <head>
#
#
# 	<script type='text/javascript'>
# 	// FIND INDEX AND UPDATE IFRAME
#     var counter = 0;
#     var course = "red";
#     var allHorses = {}
#     var currentHorse = 2;
#
#     var horseLinks =[];
#     var allLinks = [];
#
#     function findIndex(arr,obj) {
#  	var ind = arr.indexOf(obj);
#  	if (ind > -1){
# 		return ind;
# 	} else {
# 		return counter;
# 	}
#
# }
#
# function updateIframe(index){
#
#      	alert(horseLinks);
#      	alert(index);
#
#         if (index < 0){
#             index += horseLinks.length;
#         }
#
#         counter = index;
#
#         alert("update " + horseLinks[counter]);
#
#         var url = horseLinks[index%horseLinks.length]['href'];
#
#         alert("update url " + url);
#         document.getElementById('horseFrame').src = url;
#         return false;
#     }
# </script>
#
# <script>
# // Check if race matches course
# // Return boolean to wnable combinations
# var filterByCourse = function(race){
# 	return race['course'].toLowerCase() === course;
# }
#
# </script>
#
# <script>
# var changeHorse = function()
# {
# var mylist=document.getElementById("horses");
# document.getElementById("horseName").innerHTML="<strong>"+mylist.options[mylist.selectedIndex].text+"</strong>";
# currentHorse = allHorses[mylist.options[mylist.selectedIndex].text];
# return  raceLinksFromHorse(currentHorse,filterByCourse);
# }
# </script>
#
# <script>
# // {"going": "GF", "distNext": "4.75L Norse Blues 8-8)", "jockey": "Connor Beasley", "weight": 118, "rpr": "*", "raceClass": "C2Hc", "///// price": 25.0, "pos": 6, "value": 16, "ts": "*", "course": "Thi", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=////// 576401", "date": "04May13", "furlongs": 8, "OR": 92, "runners": 15}
#
# function prettyPrintOneRace(race){
#
# 	var pretty = '<a href="#" onclick="updateIframe(' + race["index"] + '); return false">' +
# 		race['date'] + " " + race['course'] + race['raceClass'] + " " + race['weight'] + "lbs " +
# 		race['pos'] + "/" + race['runners'] + " " + race['distNext'] + " " + race['price'] + " " +
# 		race['jockey'] + " " + race['OR'] + "</a>";
#
# 		return pretty;
# }
#
# var changeHorse = function()
# {
#
# var mylist=document.getElementById("horses");
#
# document.getElementById("horseName").innerHTML="<strong>"+mylist.options[mylist.selectedIndex].text+"</strong>";
# currentHorse = allHorses[mylist.options[mylist.selectedIndex].text];
# return  raceLinksFromHorse(currentHorse,filterByCourse);
# }
#
# </script>
#
#     </head>
#
#     <body >
#
#
# <script type='text/javascript'>;
#  var jsonString = '{"races": "", "href": "http://www.racingpost.com/horses/horse_home.sd?horse_id=788231", "name": "Crossley"}';
#         var Crossley = JSON.parse(jsonString);
#
#      var races = [];
# 	var string = '{"going": "Hy", "distNext": "2.5L Kuwait Star 9-6)", "jockey": "Barry McHugh", "weight": 123, "rpr": "*", "raceClass": "C53yHc", "price": 25.0, "pos": 4, "value": 2, "ts": "*", "course": "Red", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=565605", "date": "06Nov12", "furlongs": 7, "OR": 60, "runners": 12}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "GS", "distNext": "21L A*Juba 9-3)", "jockey": "Tony Hamilton", "weight": 129, "rpr": "*", "raceClass": "C53yMd", "price": 66.0, "pos": 6, "value": 2, "ts": "*", "course": "Pon", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=563925", "date": "08Oct12", "furlongs": 8, "OR": 63, "runners": 11}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "GF", "distNext": "10L Annie Walker 9-2)", "jockey": "Dale Swift", "weight": 126, "rpr": "*", "raceClass": "C53yHc", "price": 22.0, "pos": 10, "value": 2, "ts": "*", "course": "Bev", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=555096", "date": "02Jun12", "furlongs": 7, "OR": 66, "runners": 14}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "Sft", "distNext": "6.5L Exclusive Dancer 8-8)", "jockey": "Dale Swift", "weight": 122, "rpr": "*", "raceClass": "C5Md", "price": 8.0, "pos": 8, "value": 2, "ts": "*", "course": "Thi", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=553216", "date": "12May12", "furlongs": 8, "OR": 67, "runners": 14}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "GS", "distNext": "5.25L Willie Wag Tail 9-3)", "jockey": "Dale Swift", "weight": 126, "rpr": "*", "raceClass": "C62yMd", "price": 7.0, "pos": 3, "value": 1, "ts": "*", "course": "Red", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=539752", "date": "14Oct11", "furlongs": 8, "OR": 0, "runners": 7}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "GF", "distNext": "12.5L Glamorous Angel 9-3)", "jockey": "Dale Swift", "weight": 126, "rpr": "*", "raceClass": "C42yMd", "price": 25.0, "pos": 5, "value": 4, "ts": "*", "course": "Pon", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=538726", "date": "22Sep11", "furlongs": 6, "OR": 0, "runners": 10}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "GF", "distNext": "13L Asatir 9-3)", "jockey": "Phillip Makin", "weight": 129, "rpr": "*", "raceClass": "C52yMd", "price": 80.0, "pos": 8, "value": 2, "ts": "*", "course": "Red", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=535029", "date": "17Jul11", "furlongs": 7, "OR": 0, "runners": 12}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
#  Crossley['races'] = races;
#  allHorses['Crossley'] = Crossley;
#
#     </script>
# <script type='text/javascript'>;
#  var jsonString = '{"races": "", "href": "http://www.racingpost.com/horses/horse_home.sd?horse_id=769578", "name": "Deliberation"}';
#         var Deliberation = JSON.parse(jsonString);
#
#      var races = [];
# 	var string = '{"going": "GF", "distNext": "14.5L Sleepy Blue Ocean 9-2)", "jockey": "Julie Burke", "weight": 125, "rpr": "*", "raceClass": "C5Hc", "price": 50.0, "pos": 15, "value": 2, "ts": "*", "course": "Don", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=559640", "date": "26Jul12", "furlongs": 6, "OR": 65, "runners": 17}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "GF", "distNext": "38L Green Park 9-4) p", "jockey": "Graham Lee", "weight": 128, "rpr": "*", "raceClass": "C5Hc", "price": 20.0, "pos": 8, "value": 4, "ts": "*", "course": "Chs", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=554417", "date": "26May12", "furlongs": 6, "OR": 70, "runners": 10}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "Gd", "distNext": "14L Italian Tom 9-0)", "jockey": "Royston Ffrench", "weight": 127, "rpr": "*", "raceClass": "C4Hc", "price": 66.0, "pos": 15, "value": 5, "ts": "*", "course": "Don", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=553783", "date": "19May12", "furlongs": 6, "OR": 74, "runners": 18}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "Hy", "distNext": "14.5L Long Awaited 9-5)", "jockey": "Royston Ffrench", "weight": 124, "rpr": "*", "raceClass": "C4Hc", "price": 25.0, "pos": 13, "value": 4, "ts": "*", "course": "Don", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=554505", "date": "27Apr12", "furlongs": 5, "OR": 75, "runners": 13}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "St", "distNext": "13L Encore Un Fois 8-13)", "jockey": "Kieren Fallon", "weight": 123, "rpr": "*", "raceClass": "C63yCl", "price": 3.0, "pos": 4, "value": 1, "ts": "*", "course": "Kem", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=543952", "date": "21Dec11", "furlongs": 8, "OR": 57, "runners": 4}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "St", "distNext": "14.5L Global Village 8-7)", "jockey": "Paul McGiff", "weight": 110, "rpr": "*", "raceClass": "C6Cl", "price": 33.0, "pos": 10, "value": 1, "ts": "*", "course": "Sth", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=543120", "date": "06Dec11", "furlongs": 6, "OR": 62, "runners": 13}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "St", "distNext": "11L Take Cover 9-11)", "jockey": "Julie Burke", "weight": 128, "rpr": "*", "raceClass": "C6Hc", "price": 9.0, "pos": 6, "value": 1, "ts": "*", "course": "Sth", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=542141", "date": "22Nov11", "furlongs": 6, "OR": 65, "runners": 11}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "Sft", "distNext": "2.75L Sam Nombulist 9-3)", "jockey": "Sam James", "weight": 125, "rpr": "*", "raceClass": "C5Hc", "price": 16.0, "pos": 2, "value": 2, "ts": "*", "course": "Don", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=540937", "date": "05Nov11", "furlongs": 7, "OR": 73, "runners": 15}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "St", "distNext": "5.25L Frequency 9-7)", "jockey": "Amy Ryan", "weight": 127, "rpr": "*", "raceClass": "C5Hc", "price": 2.5, "pos": 9, "value": 1, "ts": "*", "course": "Wol", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=540535", "date": "29Oct11", "furlongs": 6, "OR": 68, "runners": 11}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "Sft", "distNext": "1.5L Rowan Spirit 9-0)", "jockey": "Julie Burke", "weight": 128, "rpr": "*", "raceClass": "C53yHc", "price": 4.5, "pos": 2, "value": 2, "ts": "*", "course": "Cat", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=540460", "date": "25Oct11", "furlongs": 6, "OR": 73, "runners": 8}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "Sft", "distNext": "10.5L Hills Of Dakota 9-4)", "jockey": "Julie Burke", "weight": 131, "rpr": "*", "raceClass": "C53yHc", "price": 2.25, "pos": 6, "value": 2, "ts": "*", "course": "Ham", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=538409", "date": "18Sep11", "furlongs": 6, "OR": 73, "runners": 8}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "GS", "distNext": "1L Blue Deer 8-9)", "jockey": "Julie Burke", "weight": 121, "rpr": "*", "raceClass": "C53yHc", "price": 1.875, "pos": 1, "value": 3, "ts": "*", "course": "Eps", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=537989", "date": "08Sep11", "furlongs": 6, "OR": 68, "runners": 8}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "GS", "distNext": "1.5L Inca Blue 9-0)", "jockey": "Julie Burke", "weight": 132, "rpr": "*", "raceClass": "C63yHc", "price": 1.25, "pos": 1, "value": 1, "ts": "*", "course": "Ham", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=537241", "date": "26Aug11", "furlongs": 6, "OR": 63, "runners": 7}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "Gd", "distNext": "2.25L Tahitian Princess 9-4)", "jockey": "Julie Burke", "weight": 127, "rpr": "*", "raceClass": "C63yHc", "price": 2.125, "pos": 1, "value": 1, "ts": "*", "course": "Ham", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=536881", "date": "18Aug11", "furlongs": 6, "OR": 57, "runners": 6}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "Gd", "distNext": "9.75L One Of Twins 8-3)", "jockey": "Phillip Makin", "weight": 128, "rpr": "*", "raceClass": "C63yHc", "price": 7.5, "pos": 8, "value": 2, "ts": "*", "course": "Cat", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=536037", "date": "02Aug11", "furlongs": 7, "OR": 60, "runners": 13}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "Gd", "distNext": "2L Weetentherty 9-3)", "jockey": "P J McDonald", "weight": 126, "rpr": "*", "raceClass": "C6MdSl", "price": 1.4, "pos": 4, "value": 2, "ts": "*", "course": "Ham", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=534562", "date": "09Jul11", "furlongs": 6, "OR": 65, "runners": 10}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "St", "distNext": "34L Twice Red 9-3)", "jockey": "Tom Eaves", "weight": 129, "rpr": "*", "raceClass": "C53yMd", "price": 33.0, "pos": 8, "value": 1, "ts": "*", "course": "Sth", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=524978", "date": "15Mar11", "furlongs": 6, "OR": 0, "runners": 8}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "St", "distNext": "18L Take Your Partner 8-13)", "jockey": "Tom Eaves", "weight": 125, "rpr": "*", "raceClass": "C6Md", "price": 5.0, "pos": 9, "value": 1, "ts": "*", "course": "Sth", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=523580", "date": "24Feb11", "furlongs": 5, "OR": 0, "runners": 9}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "GS", "distNext": "3.5L Magnini 9-3)", "jockey": "Barry McHugh", "weight": 129, "rpr": "*", "raceClass": "C62yMd", "price": 16.0, "pos": 3, "value": 2, "ts": "*", "course": "Cat", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=515632", "date": "26Oct10", "furlongs": 6, "OR": 0, "runners": 10}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
#  Deliberation['races'] = races;
#  allHorses['Deliberation'] = Deliberation;
#
#     </script>
# <script type='text/javascript'>;
#  var jsonString = '{"races": "", "href": "http://www.racingpost.com/horses/horse_home.sd?horse_id=744950", "name": "Cross The Boss"}';
#         var CrossTheBoss = JSON.parse(jsonString);
#
#      var races = [];
# 	var string = '{"going": "Gd", "distNext": "6.75L Never Forever 9-5)", "jockey": "Graham Gibbons", "weight": 121, "rpr": "*", "raceClass": "C5Hc", "price": 2.75, "pos": 11, "value": 2, "ts": "*", "course": "Ncs", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=578863", "date": "01Jun13", "furlongs": 8, "OR": 58, "runners": 14}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "Gd", "distNext": "0.25L Spavento 9-5)", "jockey": "Daniel Tudhope", "weight": 123, "rpr": "*", "raceClass": "C6Hc", "price": 3.0, "pos": 2, "value": 1, "ts": "*", "course": "Ncs", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=575782", "date": "25Apr13", "furlongs": 8, "OR": 55, "runners": 15}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "St", "distNext": "5L Stylistickhill 9-3) t", "jockey": "Phillip Makin", "weight": 128, "rpr": "*", "raceClass": "C6Hc", "price": 1.1, "pos": 8, "value": 2, "ts": "*", "course": "Wol", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=564409", "date": "20Oct12", "furlongs": 9, "OR": 60, "runners": 12}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "St", "distNext": "2.5L Star City 9-6) t", "jockey": "Jamie Spencer", "weight": 136, "rpr": "*", "raceClass": "C6Hc", "price": 4.5, "pos": 5, "value": 1, "ts": "*", "course": "Wol", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=563939", "date": "08Oct12", "furlongs": 9, "OR": 60, "runners": 12}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "Gd", "distNext": "1L Thrust Control 8-13) t", "jockey": "Phillip Makin", "weight": 126, "rpr": "*", "raceClass": "C6Hc", "price": 16.0, "pos": 1, "value": 1, "ts": "*", "course": "Ncs", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=563801", "date": "10Sep12", "furlongs": 7, "OR": 50, "runners": 15}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "Gd", "distNext": "20L Gadobout Dancer 8-4) t", "jockey": "David Simmonson", "weight": 121, "rpr": "*", "raceClass": "C6Hc", "price": 16.0, "pos": 10, "value": 2, "ts": "*", "course": "Bev", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=561757", "date": "01Sep12", "furlongs": 10, "OR": 53, "runners": 10}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "Gd", "distNext": "13L Indian Giver 9-5) t", "jockey": "P J McDonald", "weight": 130, "rpr": "*", "raceClass": "C6Hc", "price": 16.0, "pos": 6, "value": 1, "ts": "*", "course": "Red", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=560039", "date": "01Aug12", "furlongs": 8, "OR": 55, "runners": 12}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "GS", "distNext": "21L Classic Descent 8-10) t", "jockey": "David Allan", "weight": 126, "rpr": "*", "raceClass": "C6Hc", "price": 5.5, "pos": 13, "value": 2, "ts": "*", "course": "Rip", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=533045", "date": "16Jun11", "furlongs": 8, "OR": 58, "runners": 13}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "GF", "distNext": "7.25L Spavento 9-2) t", "jockey": "P J McDonald", "weight": 133, "rpr": "*", "raceClass": "C6Hc", "price": 10.0, "pos": 3, "value": 1, "ts": "*", "course": "Ncs", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=529690", "date": "13May11", "furlongs": 8, "OR": 60, "runners": 14}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "GF", "distNext": "3.75L No Quarter 8-7) t", "jockey": "Phillip Makin", "weight": 125, "rpr": "*", "raceClass": "C5Hc", "price": 10.0, "pos": 5, "value": 2, "ts": "*", "course": "Red", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=528229", "date": "25Apr11", "furlongs": 7, "OR": 61, "runners": 13}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "GS", "distNext": "1L Moran 10-12) t", "jockey": "Barry Keniry", "weight": 152, "rpr": "*", "raceClass": "C44yH", "price": 66.0, "pos": -1, "value": 2, "ts": "*", "course": "Don", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=523638", "date": "23Feb11", "furlongs": 17, "OR": 0, "runners": 15}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "St", "distNext": "3.5L Elijah Pepper 9-6) t", "jockey": "Phillip Makin", "weight": 123, "rpr": "*", "raceClass": "C5Hc", "price": 2.25, "pos": 5, "value": 2, "ts": "*", "course": "Wol", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=514908", "date": "16Oct10", "furlongs": 9, "OR": 61, "runners": 11}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "St", "distNext": "1L Philosophers Guest 9-0) t", "jockey": "Phillip Makin", "weight": 126, "rpr": "*", "raceClass": "C6Hc", "price": 7.5, "pos": 1, "value": 1, "ts": "*", "course": "Wol", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=513824", "date": "24Sep10", "furlongs": 9, "OR": 55, "runners": 11}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "Gd", "distNext": "14.5L Catawollow 7-13) t", "jockey": "Jerry O*Dwyer", "weight": 126, "rpr": "*", "raceClass": "C63yHc", "price": 7.0, "pos": 9, "value": 2, "ts": "*", "course": "Ncs", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=506356", "date": "28May10", "furlongs": 8, "OR": 56, "runners": 15}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "GF", "distNext": "2.5L Princess Lexi 8-5) t", "jockey": "Phillip Makin", "weight": 127, "rpr": "*", "raceClass": "C63yHc", "price": 12.0, "pos": 3, "value": 1, "ts": "*", "course": "Red", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=507247", "date": "10May10", "furlongs": 8, "OR": 56, "runners": 13}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "GF", "distNext": "22L Our Boy Barrington 9-4) t", "jockey": "J-P Guillambert", "weight": 123, "rpr": "*", "raceClass": "C63yHc", "price": 25.0, "pos": 14, "value": 2, "ts": "*", "course": "Not", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=502344", "date": "17Apr10", "furlongs": 8, "OR": 58, "runners": 14}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "St", "distNext": "13L Hacienda 9-3) t", "jockey": "Patrick Donaghy", "weight": 124, "rpr": "*", "raceClass": "C53yMd", "price": 50.0, "pos": 5, "value": 2, "ts": "*", "course": "Wol", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=497436", "date": "01Feb10", "furlongs": 7, "OR": 0, "runners": 12}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "St", "distNext": "6.25L Duellist 8-9) t", "jockey": "Patrick Donaghy", "weight": 116, "rpr": "*", "raceClass": "C5Md", "price": 50.0, "pos": 4, "value": 2, "ts": "*", "course": "Wol", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=496639", "date": "22Jan10", "furlongs": 7, "OR": 0, "runners": 8}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "Gd", "distNext": "31L Rashaad 9-3)", "jockey": "Phillip Makin", "weight": 129, "rpr": "*", "raceClass": "C42yMd", "price": 100.0, "pos": 12, "value": 4, "ts": "*", "course": "Don", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=493263", "date": "23Oct09", "furlongs": 7, "OR": 0, "runners": 13}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
#  CrossTheBoss['races'] = races;
#  allHorses['Cross The Boss'] = CrossTheBoss;
#
#     </script>
# <script type='text/javascript'>;
#  var jsonString = '{"races": "", "href": "http://www.racingpost.com/horses/horse_home.sd?horse_id=790691", "name": "For Shia And Lula"}';
#         var ForShiaAndLula = JSON.parse(jsonString);
#
#      var races = [];
# 	var string = '{"going": "Fm", "distNext": "0.5L Perfect Outlook 8-12)", "jockey": "Shane Kelly", "weight": 133, "rpr": "*", "raceClass": "C6Hc", "price": 3.5, "pos": 1, "value": 1, "ts": "*", "course": "Bat", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=579019", "date": "06May13", "furlongs": 8, "OR": 55, "runners": 9}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "St", "distNext": "2.75L Sinchiroka 8-2)", "jockey": "Darren Egan", "weight": 126, "rpr": "*", "raceClass": "C5Hc", "price": 4.0, "pos": 7, "value": 2, "ts": "*", "course": "Wol", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=573092", "date": "15Mar13", "furlongs": 9, "OR": 66, "runners": 7}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "St", "distNext": "0.5L Mafi 8-11)", "jockey": "Shane Kelly", "weight": 130, "rpr": "*", "raceClass": "C5Hc", "price": 8.0, "pos": 4, "value": 2, "ts": "*", "course": "Lin", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=571889", "date": "22Feb13", "furlongs": 8, "OR": 66, "runners": 7}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "St", "distNext": "0.5L Faithful Ruler 8-5)", "jockey": "Shane Kelly", "weight": 126, "rpr": "*", "raceClass": "C6Cl", "price": 16.0, "pos": 2, "value": 1, "ts": "*", "course": "Wol", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=571140", "date": "04Feb13", "furlongs": 9, "OR": 67, "runners": 4}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "St", "distNext": "1.75L Jack My Boy 9-0)", "jockey": "Ryan Clark", "weight": 130, "rpr": "*", "raceClass": "C5Hc", "price": 6.0, "pos": 4, "value": 2, "ts": "*", "course": "Lin", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=570761", "date": "31Jan13", "furlongs": 7, "OR": 67, "runners": 6}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "St", "distNext": "6.25L Lord Of The Dance 9-0)", "jockey": "Shane Kelly", "weight": 130, "rpr": "*", "raceClass": "C5Hc", "price": 9.0, "pos": 5, "value": 2, "ts": "*", "course": "Wol", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=570737", "date": "28Jan13", "furlongs": 7, "OR": 67, "runners": 10}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "St", "distNext": "3L Silverware 9-7)", "jockey": "Shane Kelly", "weight": 126, "rpr": "*", "raceClass": "C5Hc", "price": 16.0, "pos": 5, "value": 2, "ts": "*", "course": "Wol", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=568882", "date": "28Dec12", "furlongs": 7, "OR": 68, "runners": 11}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "St", "distNext": "1.25L Efistorm 8-4)", "jockey": "Shane Kelly", "weight": 123, "rpr": "*", "raceClass": "C6Cl", "price": 12.0, "pos": 4, "value": 1, "ts": "*", "course": "Lin", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=569182", "date": "11Dec12", "furlongs": 6, "OR": 67, "runners": 10}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "St", "distNext": "2.5L Mother Jones 8-12) eb1", "jockey": "Shane Kelly", "weight": 131, "rpr": "*", "raceClass": "C5Hc", "price": 22.0, "pos": 4, "value": 2, "ts": "*", "course": "Wol", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=566492", "date": "24Nov12", "furlongs": 6, "OR": 68, "runners": 12}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "St", "distNext": "13L Diman Waters 8-13) p", "jockey": "Matthew Lawson", "weight": 127, "rpr": "*", "raceClass": "C5Hc", "price": 12.0, "pos": 11, "value": 2, "ts": "*", "course": "Wol", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=565644", "date": "09Nov12", "furlongs": 6, "OR": 70, "runners": 12}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "St/Slw", "distNext": "2.75L Muhdiq 9-5) p", "jockey": "Shane Kelly", "weight": 128, "rpr": "*", "raceClass": "C5Hc", "price": 10.0, "pos": 6, "value": 2, "ts": "*", "course": "Lin", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=564727", "date": "23Oct12", "furlongs": 5, "OR": 72, "runners": 10}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "St", "distNext": "4.5L Drawnfromthepast 9-5) p", "jockey": "Martin Harley", "weight": 130, "rpr": "*", "raceClass": "C5Hc", "price": 7.5, "pos": 8, "value": 2, "ts": "*", "course": "Wol", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=565928", "date": "18Oct12", "furlongs": 5, "OR": 72, "runners": 13}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "St", "distNext": "5L Amoure Medici 9-5) p", "jockey": "Stephen Craine", "weight": 128, "rpr": "*", "raceClass": "C5Hc", "price": 20.0, "pos": 4, "value": 2, "ts": "*", "course": "Wol", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=563221", "date": "27Sep12", "furlongs": 6, "OR": 72, "runners": 12}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "St/Fs", "distNext": "1L Dancing Maite 8-11)", "jockey": "Stephen Craine", "weight": 129, "rpr": "*", "raceClass": "C5Hc", "price": 8.0, "pos": 2, "value": 2, "ts": "*", "course": "Wol", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=564509", "date": "22Sep12", "furlongs": 6, "OR": 72, "runners": 6}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "GF", "distNext": "6.25L Forest Edge 9-4)", "jockey": "Stephen Craine", "weight": 129, "rpr": "*", "raceClass": "C53yHc", "price": 16.0, "pos": 7, "value": 2, "ts": "*", "course": "Lei", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=560629", "date": "12Aug12", "furlongs": 6, "OR": 63, "runners": 7}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "GF", "distNext": "5.25L Plum Bay 8-6)", "jockey": "Kieren Fallon", "weight": 130, "rpr": "*", "raceClass": "C53yHc", "price": 6.0, "pos": 4, "value": 2, "ts": "*", "course": "Nmk", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=560091", "date": "03Aug12", "furlongs": 6, "OR": 65, "runners": 9}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "GF", "distNext": "13.5L Our Boy Jack 9-1)", "jockey": "Frederik Tylicki", "weight": 133, "rpr": "*", "raceClass": "C53yHc", "price": 16.0, "pos": 7, "value": 3, "ts": "*", "course": "Mus", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=554402", "date": "25May12", "furlongs": 7, "OR": 70, "runners": 7}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "Sft", "distNext": "24L Hajras 8-8)", "jockey": "Padraig Beggy", "weight": 119, "rpr": "*", "raceClass": "C33yHc", "price": 66.0, "pos": 11, "value": 6, "ts": "*", "course": "Rip", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=551156", "date": "19Apr12", "furlongs": 8, "OR": 75, "runners": 12}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "St", "distNext": "3.5L Tones 9-0)", "jockey": "Shane Kelly", "weight": 126, "rpr": "*", "raceClass": "C42yHc", "price": 8.5, "pos": 6, "value": 4, "ts": "*", "course": "Wol", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=541724", "date": "19Nov11", "furlongs": 7, "OR": 76, "runners": 9}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "St", "distNext": "1L Ashbina 8-12)", "jockey": "Shane Kelly", "weight": 129, "rpr": "*", "raceClass": "C52yMd", "price": 20.0, "pos": 1, "value": 2, "ts": "*", "course": "Wol", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=538733", "date": "22Sep11", "furlongs": 6, "OR": 0, "runners": 8}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "Gd", "distNext": "12L Crusade 9-3)", "jockey": "Seamie Heffernan", "weight": 129, "rpr": "*", "raceClass": "2y", "price": 100.0, "pos": 9, "value": 10, "ts": "*", "course": "Cur", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=538627", "date": "28Aug11", "furlongs": 6, "OR": 0, "runners": 16}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "Gd", "distNext": "21L Perfect Godess 8-1)", "jockey": "W J Supple", "weight": 123, "rpr": "*", "raceClass": "2y", "price": 40.0, "pos": 12, "value": 6, "ts": "*", "course": "Sli", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=537393", "date": "03Aug11", "furlongs": 7, "OR": 0, "runners": 14}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
#  ForShiaAndLula['races'] = races;
#  allHorses['For Shia And Lula'] = ForShiaAndLula;
#
#     </script>
# <script type='text/javascript'>;
#  var jsonString = '{"races": "", "href": "http://www.racingpost.com/horses/horse_home.sd?horse_id=783445", "name": "Dolly Diva"}';
#         var DollyDiva = JSON.parse(jsonString);
#
#      var races = [];
#  DollyDiva['races'] = races;
#  allHorses['Dolly Diva'] = DollyDiva;
#
#     </script>
# <script type='text/javascript'>;
#  var jsonString = '{"races": "", "href": "http://www.racingpost.com/horses/horse_home.sd?horse_id=762233", "name": "Inca Chief"}';
#         var IncaChief = JSON.parse(jsonString);
#
#      var races = [];
# 	var string = '{"going": "GF", "distNext": "1L For Livvy 10-5)", "jockey": "Graham Lee", "weight": 152, "rpr": "*", "raceClass": "C43yH", "price": 14.0, "pos": -1, "value": 2, "ts": "*", "course": "Hex", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=532028", "date": "04Jun11", "furlongs": 17, "OR": 0, "runners": 8}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "GF", "distNext": "18L Coax 9-7) t", "jockey": "Paul Mulrennan", "weight": 127, "rpr": "*", "raceClass": "C63yHc", "price": 14.0, "pos": 10, "value": 1, "ts": "*", "course": "Bev", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=528907", "date": "02May11", "furlongs": 7, "OR": 59, "runners": 11}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "Fm", "distNext": "18L Buzz Law 9-1)", "jockey": "Paul Hanagan", "weight": 120, "rpr": "*", "raceClass": "C53yHc", "price": 8.0, "pos": 8, "value": 3, "ts": "*", "course": "Red", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=527610", "date": "18Apr11", "furlongs": 8, "OR": 62, "runners": 8}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "Gd", "distNext": "13L Glencadam Gold 9-3)", "jockey": "Silvestre De Sousa", "weight": 129, "rpr": "*", "raceClass": "C62yMd", "price": 33.0, "pos": 3, "value": 1, "ts": "*", "course": "Red", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=514885", "date": "15Oct10", "furlongs": 8, "OR": 0, "runners": 16}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "Sft", "distNext": "44L Genius Beast 9-0)", "jockey": "Paul Mulrennan", "weight": 126, "rpr": "*", "raceClass": "C52yMd", "price": 33.0, "pos": 9, "value": 3, "ts": "*", "course": "Hay", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=513841", "date": "25Sep10", "furlongs": 8, "OR": 0, "runners": 10}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "St", "distNext": "14.5L Fifth Dimension 8-13)", "jockey": "Royston Ffrench", "weight": 124, "rpr": "*", "raceClass": "C52yMdAc", "price": 2.0, "pos": 11, "value": 2, "ts": "*", "course": "Wol", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=509616", "date": "06Jul10", "furlongs": 7, "OR": 0, "runners": 11}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
#  IncaChief['races'] = races;
#  allHorses['Inca Chief'] = IncaChief;
#
#     </script>
# <script type='text/javascript'>;
#  var jsonString = '{"races": "", "href": "http://www.racingpost.com/horses/horse_home.sd?horse_id=685115", "name": "Dhhamaan"}';
#         var Dhhamaan = JSON.parse(jsonString);
#
#      var races = [];
# 	var string = '{"going": "St", "distNext": "12.5L Bold Ring 9-11) b", "jockey": "James Sullivan", "weight": 127, "rpr": "*", "raceClass": "C6Hc", "price": 6.0, "pos": 8, "value": 1, "ts": "*", "course": "Kem", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=578504", "date": "07May13", "furlongs": 7, "OR": 48, "runners": 10}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "GS", "distNext": "22L Jebel Tara 8-7) b", "jockey": "P J McDonald", "weight": 121, "rpr": "*", "raceClass": "C6Hc", "price": 12.0, "pos": 7, "value": 2, "ts": "*", "course": "Mus", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=578685", "date": "03May13", "furlongs": 7, "OR": 53, "runners": 8}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "St", "distNext":
"runners": 12}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "GF", "distNext": "5L Pic Up Sticks 9-2)", "jockey": "Paul Fitzsimons", "weight": 121, "rpr": "*", "raceClass": "C3Hc", "price": 22.0, "pos": 8, "value": 8, "ts": "*", "course": "Nmk", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=412664", "date": "22Jul06", "furlongs": 5, "OR": 79, "runners": 9}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "GF", "distNext": "6.5L Malapropism 9-10)", "jockey": "Paul Fitzsimons", "weight": 136, "rpr": "*", "raceClass": "C3Hc", "price": 8.0, "pos": 5, "value": 8, "ts": "*", "course": "Yor", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=412219", "date": "14Jul06", "furlongs": 5, "OR": 83, "runners": 6}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "Gd", "distNext": "12L Glenviews Youngone 8-4) b1", "jockey": "Paul Fitzsimons", "weight": 127, "rpr": "*", "raceClass": "C23yHc", "price": 33.0, "pos": 9, "value": 14, "ts": "*", "course": "Not", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=408945", "date": "01Jun06", "furlongs": 5, "OR": 87, "runners": 9}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "GF", "distNext": "6.5L Empress Jain 9-4)", "jockey": "Paul Fitzsimons", "weight": 128, "rpr": "*", "raceClass": "C23yHc", "price": 8.5, "pos": 9, "value": 14, "ts": "*", "course": "Chs", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=406805", "date": "11May06", "furlongs": 5, "OR": 90, "runners": 12}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "Gd", "distNext": "0.5L Blazing Heights 8-4)", "jockey": "Royston Ffrench", "weight": 131, "rpr": "*", "raceClass": "C32yHc", "price": 9.0, "pos": 1, "value": 11, "ts": "*", "course": "Mus", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=392038", "date": "16Oct05", "furlongs": 5, "OR": 87, "runners": 10}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "Gd", "distNext": "3L Come Out Fighting 9-2)", "jockey": "Joe Fanning", "weight": 133, "rpr": "*", "raceClass": "C22yHc", "price": 8.0, "pos": 5, "value": 12, "ts": "*", "course": "Mus", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=390804", "date": "12Sep05", "furlongs": 5, "OR": 89, "runners": 12}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "GF", "distNext": "5.5L Playful 8-9)", "jockey": "Darren Williams", "weight": 124, "rpr": "*", "raceClass": "C32y", "price": 8.0, "pos": 4, "value": 6, "ts": "*", "course": "Rip", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=390248", "date": "30Aug05", "furlongs": 5, "OR": 93, "runners": 8}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "Gd", "distNext": "5.5L Tabaret 8-11) v1", "jockey": "Darren Williams", "weight": 123, "rpr": "*", "raceClass": "C12yL", "price": 9.0, "pos": 7, "value": 18, "ts": "*", "course": "Yor", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=389621", "date": "17Aug05", "furlongs": 5, "OR": 95, "runners": 10}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "GF", "distNext": "6.75L Lady Livius 8-5)", "jockey": "Darren Williams", "weight": 118, "rpr": "*", "raceClass": "C22y", "price": 6.0, "pos": 16, "value": 78, "ts": "*", "course": "Nby", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=379006", "date": "16Jul05", "furlongs": 5, "OR": 0, "runners": 25}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "Gd", "distNext": "3.5L Curtail 9-3)", "jockey": "Darren Williams", "weight": 133, "rpr": "*", "raceClass": "C32yHc", "price": 14.0, "pos": 1, "value": 8, "ts": "*", "course": "Yor", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=387654", "date": "09Jul05", "furlongs": 5, "OR": 84, "runners": 9}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "GS", "distNext": "8L Indigo Nights 8-4)", "jockey": "Darren Williams", "weight": 127, "rpr": "*", "raceClass": "C52yNvAc", "price": 3.5, "pos": 6, "value": 3, "ts": "*", "course": "Crl", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=386118", "date": "14Jun05", "furlongs": 5, "OR": 0, "runners": 8}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "GF", "distNext": "0.5L Royal Power 9-0)", "jockey": "Darren Williams", "weight": 126, "rpr": "*", "raceClass": "C52yMd", "price": 3.5, "pos": 1, "value": 5, "ts": "*", "course": "Thi", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=385162", "date": "03Jun05", "furlongs": 5, "OR": 0, "runners": 13}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "Gd", "distNext": "3.25L Mullaad 8-12)", "jockey": "Darren Williams", "weight": 124, "rpr": "*", "raceClass": "C52yNv", "price": 33.0, "pos": 5, "value": 3, "ts": "*", "course": "Ncs", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=383864", "date": "19May05", "furlongs": 5, "OR": 0, "runners": 7}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
# 	var string = '{"going": "GF", "distNext": "4.25L Lake Hero 8-4)", "jockey": "Darren Williams", "weight": 123, "rpr": "*", "raceClass": "C52yMdAc", "price": 12.0, "pos": 5, "value": 3, "ts": "*", "course": "Mus", "href": "http://www.racingpost.com/horses/result_home.sd?race_id=380564", "date": "12Apr05", "furlongs": 5, "OR": 0, "runners": 9}';
# 	var raceobj = JSON.parse(string);
# 	races.push(raceobj);
#  Triskaidekaphobia['races'] = races;
#  allHorses['Triskaidekaphobia'] = Triskaidekaphobia;
#
#     </script>
# <select id ="horses" onchange="changeHorse()">
# <option value=Crossley>Crossley</option>
# <option value=Deliberation>Deliberation</option>
# <option value=CrossTheBoss>Cross The Boss</option>
# <option value=ForShiaAndLula>For Shia And Lula</option>
# <option value=DollyDiva>Dolly Diva</option>
# <option value=IncaChief>Inca Chief</option>
# <option value=Dhhamaan>Dhhamaan</option>
# <option value=Yourelikemefrank>You relikemefrank</option>
# <option value=JayKay>Jay Kay</option>
# <option value=ArtilleryTrain>Artillery Train</option>
# <option value=ZoomIn>Zoom In</option>
# <option value=Triskaidekaphobia>Triskaidekaphobia</option>
#
# </select>
#
#     <table width="1200px" border="2" id="horseCarouselTable">
#
#     <tr>
#
#     <td rowspan="2" id="horseCarouselNavigation">
#     <a href="#" onclick="updateIframe(counter+1); return false">
#     <img src="leftArrow.gif"/>
# 	</a>
#     <br />
#     <a href="#" onclick="updateIframe(counter-1); return false"><img src="rightArrow.gif"/></a>
#     </td>
#     <td>Horse Form / Race Name</td>
#
#     <td>H2H Horses</td>
#     </tr>
#
#     <tr>
#
#     <td id= "horseName">Race name to appear here</td>
#
#     <td id= "horseCarouselH2H">Other horses from both races here</td>
#     </tr>
#
#     </table>
#
#     <br />
#
#
#                 <iframe
#                 	id = "horseFrame"
#                     width="800"
#                     height="600"
#                     src="http://www.google.com"
#                     frameborder="0"
#
#
#                 ></iframe>
#
#
#                 <script>
#
#
#
#
#
#
# function raceLinksFromHorse(horse, filter){
#
# 	var races = horse['races'];
# 	var raceIndex=1;
# 	var hrefs = [horse];
#
# 	var hcr = document.getElementById("horseCarouselH2H");
# 	var html = ""
#
# 	alert("start");
# 	for (i=0; i<races.length;i++){
# 	 	var race = races[i];
# 	 	if (filter(race)){
# 			hrefs.push(race);
#
# 			races[i]['index'] = raceIndex;
#
# 			raceIndex+=1;
#
# 			var n = prettyPrintOneRace(race);
#
#
# 			html = html + "<li>" + n + "</li>";
#
# 		}
#
# 	}
#
# 	var t = "<ul>" + html + "</ul>";
#
#
# 	hcr.innerHTML = "" + t;
#
#
#
#
#
#
# 	return hrefs;
# }
#
# horseLinks =  changeHorse()
# alert("hl " + horseLinks);
#
#
#
#     </script>
#     </body>
# </html>
