# %%
from bs4 import BeautifulSoup

import requests

url = "python.developpez.com/tutoriels/cours-intensif-scientifique/module-numpy-scipy/"

r  = requests.get("http://" +url)

data = r.text

soup = BeautifulSoup(data)

for link in soup.find_all('p'):
    print(link.text, "\n")
# Out:
# (u'\n\n\n\n\n\n', '\n')
# (u"Pour de nombreux scientifiques, Python est LE langage de programmation par excellence, car il offre de grandes possibilit\xe9s en analyse et mod\xe9lisation de donn\xe9es scientifiques avec relativement peu de charge de travail en termes d'apprentissage, d'installation ou de temps de d\xe9veloppement. C'est un langage que vous pouvez int\xe9grer en un week-end, puis utiliser une vie durant.", '\n')
# (u'Retrouvez la premi\xe8re partie de cet article\xa0:', '\n')
# (u"Les commentaires et les suggestions d'am\xe9lioration sont les bienvenus, alors, apr\xe8s votre lecture, n'h\xe9sitez pas. 2\xa0commentaires  ", '\n')
# (u'Article lu \xa0 fois.', '\n')
# (u'Rick Muller', '\n')
# (u'Traducteur : Rapha\xebl Seban', '\n')
# (u'Publi\xe9\xa0le\xa02\xa0ao\xfbt\xa02014\xa0', '\n')
# (u'\nVersion PDF\nVersion hors-ligne', '\n')
# (u'ePub, Azw et Mobi', '\n')
# (u"La librairie Numpy contient des fonctions essentielles pour traiter les tableaux, les matrices et les op\xe9rations de type alg\xe8bre lin\xe9aire avec Python. La librairie Scipy contient des fonctions suppl\xe9mentaires pour l'optimisation de calculs, des fonctions sp\xe9ciales, etc. Les deux comprennent des modules \xe9crits en C et en Fortran de mani\xe8re \xe0 les rendre aussi rapides que possible. Utilis\xe9es ensemble, ces librairies offrent au langage Python, \xe0 peu de chose pr\xe8s, les m\xeames capacit\xe9s que Matlab\u2122. Les habitu\xe9s de ce logiciel trouveront sans doute un grand int\xe9r\xeat \xe0 lire le guide Numpy \xe0 l'attention des utilisateurs Matlab\u2122.", '\n')
# (u' ', '\n')
# (u'Cette partie est consultable \xe9galement au format \xab\xa0notebook\xa0\xbb en suivant le lien\xa0: Notes: Partie 2 - Modules NumPy et SciPy\xa0. ', '\n')
# (u"L'un des points communs fondamentaux de Numpy et de Scipy est leur aptitude \xe0 g\xe9rer les tableaux et les matrices. Vous pouvez cr\xe9er des tableaux \xe0 partir de listes Python (list ou []) gr\xe2ce \xe0 la fonction objet array():", '\n')
# (u"Vous pouvez passer en second argument de la fonction array() le type num\xe9rique souhait\xe9. Vous trouverez une liste exhaustive de ces types \xe0 cet endroit. Certains types ont un \xe9quivalent qui se r\xe9sume en une seule lettre. Les plus courants sont 'd' (nombre \xe0 virgule flottante \xe0 double pr\xe9cision), 'D' (nombre complexe \xe0 double pr\xe9cision) et 'i' (int32, entier sign\xe9 et cod\xe9 sur 32\xa0bits, valeurs allant de -2\xa0147\xa0483\xa0648 \xe0 +2\xa0147\xa0483\xa0647).", '\n')
# (u'Exemples\xa0:', '\n')
# (u'Pour cr\xe9er une matrice, vous pouvez utiliser array() avec des listes de listes Python\xa0:', '\n')
# (u'Vous pouvez aussi g\xe9n\xe9rer des matrices vides (remplies de z\xe9ros) de tailles arbitraires, y compris des tableaux unidimensionnels que Numpy traitera comme des tableaux \xe0 une seule ligne gr\xe2ce \xe0 la fonction objet zeros():', '\n')
# (u'Le premier argument de la fonction est un tuple (m_lignes, n_colonnes) et le second argument d\xe9finit le type de donn\xe9es \xe0 utiliser, comme pour la fonction objet array(). Ainsi, vous pouvez initialiser un tableau simple (une ligne) de cette fa\xe7on\xa0:', '\n')
# (u'ou des tableaux en colonne\xa0:', '\n')
# (u'Il y a aussi la fonction objet identity() qui produit, comme vous pourriez vous y attendre\xa0:', '\n')
# (u"de m\xeame que la fonction objet ones() qui fait la m\xeame chose que zeros(), sauf qu'elle initialise la matrice avec des uns (1).", '\n')
# (u'La fonction objet linspace(start, end) cr\xe9e un tableau espace lin\xe9aire de points de valeurs comprises entre start (inclus) et end (inclus).', '\n')
# (u'Si vous fournissez un troisi\xe8me argument \xe0 linspace(start, end, nb_points), celui-ci d\xe9finira le nombre de points \xe0 calculer dans cet espace lin\xe9aire. Si vous omettez ce troisi\xe8me argument, il prend par d\xe9faut la valeur nb_points=50.', '\n')
# (u"La fonction objet linspace() est un moyen bien pratique de g\xe9n\xe9rer des valeurs de coordonn\xe9es pour un graphique (NdT\xa0: pour un intervalle d'abscisses, par exemple). Les fonctions de la librairie Numpy \u2014 qui sont toutes int\xe9gr\xe9es d'office dans l'interface IPython Notebook \u2014 peuvent traiter un tableau entier (ou m\xeame une matrice) de points en une seule fois.", '\n')
# (u'Exemple\xa0:', '\n')
# (u'En alliant Numpy \xe0 la puissance de Matplotlib, nous obtenons de grandes capacit\xe9s pour tracer des graphiques facilement\xa0:', '\n')
# (u'[<matplotlib.lines.Line2D at 0x10f07a150>] ', '\n')
# (u' ', '\n')
# (u"Les objets matrice font ce qu'il faut lorsqu'ils sont multipli\xe9s par des scalaires\xa0: ", '\n')
# (u"de m\xeame, lorsque vous additionnez deux matrices entre elles (sous r\xe9serve toutefois qu'elles soient de m\xeames dimensions)\xa0:", '\n')
# (u"Une chose qui pourrait d\xe9router les utilisateurs de Matlab\u2122\xa0: l'op\xe9rateur arithm\xe9tique d\xe9not\xe9 par l'ast\xe9risque (*) applique une multiplication \xe9l\xe9ment par \xe9l\xe9ment plut\xf4t qu'une vraie multiplication entre matrices\xa0:", '\n')
# (u'Pour obtenir une vraie multiplication entre matrices, utilisez la fonction dot()\xa0:', '\n')
# (u'La fonction dot() peut aussi faire des produits scalaires\xa0:', '\n')
# (u'tout comme la multiplication matrice-tableau.', '\n')
# (u"Les fonctions determinant(), inverse() et transpose() produisent les r\xe9sultats attendus. Une transposition peut \xeatre abr\xe9g\xe9e en pla\xe7ant .T \xe0 la fin d'un nom d'objet matrice\xa0:", '\n')
# (u"Vous avez aussi la fonction diag() qui place une liste ou un tableau le long de la diagonale d'une matrice carr\xe9e.", '\n')
# (u'Nous verrons son utilit\xe9 plus tard.', '\n')
# (u"Vous pouvez r\xe9soudre des syst\xe8mes d'\xe9quations lin\xe9aires avec la fonction solve()\xa0:", '\n')
# (u'Plusieurs fonctions pour calculer des valeurs propres ainsi que des vecteurs propres\xa0:', '\n')
# (u'Maintenant que nous avons tous ces outils dans notre bo\xeete \xe0 outils, nous pouvons commencer \xe0 faire des choses int\xe9ressantes. La plupart des \xe9quations que nous cherchons \xe0 r\xe9soudre en physique implique les \xe9quations diff\xe9rentielles. Nous aimerions pouvoir calculer les d\xe9riv\xe9es de fonctions  en discr\xe9tisant la fonction  sur un espace de points  r\xe9partis uniform\xe9ment et qui produiront . Gr\xe2ce \xe0 la discr\xe9tisation des valeurs, nous pouvons approcher la d\xe9riv\xe9e  par .', '\n')
# (u'En Python, nous pourrions \xe9crire une fonction d\xe9riv\xe9e comme ceci\xa0:', '\n')
# (u"Voyons si cela fonctionne avec l'exemple sin(x) pr\xe9c\xe9dent\xa0:", '\n')
# (u'<matplotlib.legend.Legend at 0x7f0f5acd6910> ', '\n')
# (u' ', '\n')
# (u'Tr\xe8s proches\xa0! (NdT\xa0: avec seulement 15 points pour discr\xe9tiser).', '\n')
# (u"Voyons si nous pouvons utiliser ce sch\xe9ma aux diff\xe9rences finies pour calculer l'oscillateur harmonique unidimensionnel avec une bonne approximation.", '\n')
# (u"Nous aimerions r\xe9soudre l'\xe9quation ind\xe9pendante du temps de Schr\xf6dinger\xa0:", '\n')
# (u"avec  quand  repr\xe9sente le potentiel de l'oscillateur harmonique. Nous utiliserons le tour de passe-passe habituel qui consiste \xe0 transformer l'\xe9quation diff\xe9rentielle en \xe9quation matricielle, en multipliant chaque terme de l'\xe9quation par l'expression conjugu\xe9e  puis en int\xe9grant sur . Ce qui nous donne\xa0:", '\n')
# (u"NdlR\xa0:  \xe9tant une constante, nous pouvons la sortir de l'int\xe9grale, reste donc pour l'expression de droite , or  est la densit\xe9 de probabilit\xe9 de pr\xe9sence. Celle-ci, \xe9tant int\xe9gr\xe9e sur l'ensemble du domaine, vaut 1.", '\n')
# (u"Donc , d'o\xf9 la simplification de l'expression de droite \xe0 . ", '\n')
# (u"Nous allons de nouveau recourir \xe0 l'approche par diff\xe9rences finies. La formule de diff\xe9rences finies pour la d\xe9riv\xe9e seconde est\xa0:", '\n')
# (u"Nous pourrions penser au premier terme de l'\xe9quation de Schr\xf6dinger comme \xe9tant le chevauchement de la fonction d'onde  avec la d\xe9riv\xe9e seconde de la fonction d'onde . Avec la formule de la d\xe9riv\xe9e seconde que nous venons d'\xe9crire, nous pouvons v\xe9rifier que si nous prenons le chevauchement des \xe9tats  avec la d\xe9riv\xe9e seconde, nous aurons seulement trois points o\xf9 le chevauchement est non nul \xe0 ,  et . Sous la forme matricielle, cela nous m\xe8ne \xe0 la matrice tridiagonale de Laplace qui a pour valeurs des -2 dans la diagonale principale et des 1 dans les diagonales situ\xe9es au-dessus et en-dessous de cette diagonale principale.", '\n')
# (u"Le second terme de l'\xe9quation de Schr\xf6dinger m\xe8ne \xe0 une matrice diagonale avec pour \xe9l\xe9ments diagonaux . En assemblant toutes les pi\xe8ces de ce puzzle, nous obtenons\xa0:", '\n')
# (u'<matplotlib.text.Text at 0x7f6524247f90> ', '\n')
# (u' ', '\n')
# (u"Nous avons bricol\xe9 un peu pour obtenir les orbitales telles qu'attendues. Tout d'abord, nous avons ins\xe9r\xe9 un facteur -1 devant les fonctions d'onde pour r\xe9gler la phase \xe0 son \xe9tat le plus bas. La phase (signe) d'une fonction d'onde quantique ne fournit aucune information, seul le carr\xe9 de la fonction d'onde le fait, donc tout ceci est sans grande cons\xe9quence.", '\n')
# (u"En revanche, les fonctions propres telles que nous les avons g\xe9n\xe9r\xe9es ne sont pas correctement normalis\xe9es. La raison en est que la diff\xe9rence finie n'est pas un v\xe9ritable principe de base au sens de la m\xe9canique quantique. C'est le principe de base des fonctions delta \u03b4 de Dirac \xe0 chaque point\xa0; nous interpr\xe9tons les espaces entre les points comme \xe9tant \xab\xa0remplis\xa0\xbb par la fonction d'onde, mais le principe de la diff\xe9rence finie n'a de solution que pour les points eux-m\xeames. Nous pouvons r\xe9soudre ce probl\xe8me en divisant les fonctions propres de notre diff\xe9rence finie hamiltonienne par la racine carr\xe9e de l'espacement entre les points et ainsi, nous obtenons des fonctions correctement normalis\xe9es.", '\n')
# (u"Les solutions de l'oscillateur harmonique sont suppos\xe9es \xeatre des polyn\xf4mes hermitiens. La page Wikipedia a les \xe9tats HO donn\xe9s par\xa0:", '\n')
# (u"Voyons s'ils ressemblent \xe0 cela. Il existe des fonctions sp\xe9ciales dans la librairie Numpy et quelques autres encore plus sp\xe9ciales dans Scipy. Les polyn\xf4mes hermitiens se trouvent dans Numpy\xa0:", '\n')
# (u'Comparons notre premi\xe8re fonction \xe0 notre solution\xa0:', '\n')
# (u'<matplotlib.legend.Legend at 0x7f0f5aacea90> ', '\n')
# (u' ', '\n')
# (u"L'accord est presque parfait.", '\n')
# (u'Nous pouvons utiliser la fonction matplotlib subplot(rows, cols, index) pour afficher en grille plusieurs trac\xe9s dans un m\xeame graphique\xa0:', '\n')
# (u' ', '\n')
# (u"Hormis les erreurs de phase que j'ai corrig\xe9es par un petit bidouillage \u2014 vous voyez lequel\xa0? \u2014 la concordance entre les courbes est plut\xf4t pas mal, bien que cela empire au fur et \xe0 mesure que le niveau d'\xe9nergie augmente, en partie parce que nous avons utilis\xe9 une r\xe9solution de 50 points seulement.", '\n')
# (u'Le module Scipy a encore plus de fonctions sp\xe9ciales\xa0:', '\n')
# (u'<matplotlib.text.Text at 0x7f0f53792a10> ', '\n')
# (u' ', '\n')
# (u"Par exemple les polyn\xf4mes de Jacobi, Laguerre, Hermite, les fonctions hyperg\xe9om\xe9triques et plein d'autres. Vous trouverez une liste compl\xe8te sur la page fonctions sp\xe9ciales Scipy. ", '\n')
# (u'Tr\xe8s souvent, nous traitons des donn\xe9es que nous voulons cadrer avec un comportement attendu. Supposons que nous ayons ceci\xa0:', '\n')
# (u"Vous trouverez plus tard une rubrique qui traite de l'analyse de donn\xe9es au format CSV (Comma-Separated Values). Nous r\xe9cup\xe9rerons l'analyseur qui s'y trouve. Pour une explication d\xe9taill\xe9e, passez la rubrique ici pr\xe9sente et lisez plus loin. Sinon, consid\xe9rez simplement qu'il s'agit d'un moyen d'extraire un tableau Numpy de la cha\xeene de caract\xe8res raw_data, tableau que nous pourrons tracer en graphique et soumettre \xe0 diverses analyses par la suite.", '\n')
# (u'[<matplotlib.lines.Line2D at 0x7f0f5a6ea8d0>] ', '\n')
# (u' ', '\n')
# (u'Comme nous nous attendons \xe0 ce que nos donn\xe9es d\xe9croissent exponentiellement, nous pouvons utiliser une \xe9chelle semi-logarithmique\xa0:', '\n')
# (u'[<matplotlib.lines.Line2D at 0x7f0f5a746a10>] ', '\n')
# (u' ', '\n')
# (u"Pour une d\xe9croissance exponentielle pure comme celle-ci, nous pouvons assimiler les points repr\xe9sent\xe9s \xe0 une droite. Le trac\xe9 ci-dessus sugg\xe8re que nous avons l\xe0 une bonne approximation, \xe9tant donn\xe9 que la fonction ,  est du type affine. Ainsi, en ajustant l'\xe9chelle par rapport aux abscisses , nous devrions obtenir une droite de coefficient directeur  et d'ordonn\xe9e \xe0 l'origine .", '\n')
# (u"Il existe une fonction Numpy nomm\xe9e polyfit() qui ajuste les donn\xe9es pour cadrer avec une forme polynomiale. Utilisons-la pour obtenir une droite (polyn\xf4me d'ordre 1)\xa0:", '\n')
# (u"Voyons \xe0 pr\xe9sent si cette courbe s'ajuste aux donn\xe9es que nous avons\xa0:", '\n')
# (u'[<matplotlib.lines.Line2D at 0x7f0f5a9fc890>] ', '\n')
# (u' ', '\n')
# (u"Avec des fonctions plus compliqu\xe9es, il est possible que l'on n'arrive pas \xe0 s'ajuster sur un simple polyn\xf4me. Par exemple, avec les donn\xe9es suivantes\xa0:", '\n')
# (u'[<matplotlib.lines.Line2D at 0x7f0f5a6d0e10>] ', '\n')
# (u' ', '\n')
# (u"Ces donn\xe9es ressemblent plus \xe0 une courbe de Gauss qu'\xe0 une courbe exponentielle. Si nous le voulions, nous pourrions utiliser la fonction polyfit() pour ce cas aussi, mais utilisons plut\xf4t la fonction curve_fit() du module Scipy qui peut s'ajuster \xe0 toute sorte de fonctions arbitraires. Pour en savoir plus, tapez help(curve_fit) dans une cellule de code (ou en console interactive IPython).", '\n')
# (u"Tout d'abord, d\xe9finissons une fonction gaussienne g\xe9n\xe9rique \xe0 ajuster\xa0:", '\n')
# (u'\xc0 pr\xe9sent, ajustons en utilisant curve_fit()\xa0:', '\n')
# (u'[<matplotlib.lines.Line2D at 0x7f0f5043a190>] ', '\n')
# (u' ', '\n')
# (u"La fonction curve_fit() que nous venons d'utiliser est bas\xe9e sur les excellents algorithmes d'optimisation (minimisation) de Scipy. Pour en savoir plus, consultez la documentation Scipy.", '\n')
# (u"Plusieurs techniques de calcul scientifique reposent sur la m\xe9thode de Monte-Carlo o\xf9 une s\xe9quence de nombres (pseudo) al\xe9atoires est utilis\xe9e pour approcher l'int\xe9grale d'une fonction. Python a un bon g\xe9n\xe9rateur de nombres al\xe9atoires dans sa librairie standard. La fonction random() g\xe9n\xe8re des nombres pseudo-al\xe9atoires uniform\xe9ment r\xe9partis entre 0 et 1.", '\n')
# (u'[<matplotlib.lines.Line2D at 0x7f0f50375890>] ', '\n')
# (u' ', '\n')
# (u"La fonction random() se base sur l'algorithme de Mersenne Twister (page officielle) qui est un g\xe9n\xe9rateur de nombres pseudo-al\xe9atoires particuli\xe8rement appr\xe9ci\xe9. Le module Python standard random contient aussi des fonctions pour g\xe9n\xe9rer des entiers al\xe9atoires (random.randint(a, b)), des listes d'entiers al\xe9atoires (random.randrange(n)), pour m\xe9langer une liste (random.shuffle(mutable)) ainsi que des fonctions pour extraire des nombres al\xe9atoires d'une distribution particuli\xe8re telle que la distribution normale, par exemple\xa0:", '\n')
# (u'[<matplotlib.lines.Line2D at 0x7f0f50318a10>] ', '\n')
# (u' ', '\n')
# (u"Il est g\xe9n\xe9ralement plus efficace de g\xe9n\xe9rer une liste compl\xe8te de nombres al\xe9atoires en une seule op\xe9ration, surtout si vous extrayez des valeurs d'une loi non uniforme. La librairie Numpy poss\xe8de des fonctions pour g\xe9n\xe9rer des tableaux et des matrices de plusieurs lois de probabilit\xe9.", '\n')
# (u'[<matplotlib.lines.Line2D at 0x7f0f5023f7d0>] ', '\n')
# (u' ', '\n')
# (u"L'un des tous premiers programmes que j'ai \xe9crit devait servir \xe0 calculer le nombre  en prenant des nombres al\xe9atoires pour les coordonn\xe9es de points (x, y) et en comptant les occurrences situ\xe9es \xe0 l'int\xe9rieur du cercle unitaire. Par exemple\xa0:", '\n')
# (u' ', '\n')
# (u"L'id\xe9e qui sous-tend ce programme est que le ratio entre l'aire du cercle unitaire et l'aire du carr\xe9 circonscrit est de l'ordre de . Alors, en comptant la portion de points al\xe9atoires qui se trouvent \xe0 l'int\xe9rieur du cercle unitaire par rapport \xe0 l'ensemble du carr\xe9, nous obtenons une assez bonne estimation de la valeur de .", '\n')
# (u"Le bout de code pr\xe9c\xe9dent utilise des notations Numpy de haut niveau pour calculer le rayon de chaque point de coordonn\xe9es (x, y) en une seule ligne de code, puis pour compter combien de rayons sont inf\xe9rieurs \xe0 1 \u2014 toujours en une seule ligne de code \u2014 et enfin pour filtrer les points (x, y) par rapport \xe0 leurs rayons respectifs. Pour \xeatre honn\xeate, j'\xe9cris rarement du code sous cette forme\xa0: je trouve que ces techniques Numpy sont par trop pointues pour que l'on puisse s'en souvenir et je pr\xe9f\xe8re personnellement utiliser les techniques de liste en compr\xe9hension (voir plus loin) pour extraire les points que je veux, ce qui est plus facile \xe0 m\xe9moriser.", '\n')
# (u'\xc0 comparer des m\xe9thodes actuelles de calcul de , celle-ci est parmi les pires. Une bien meilleure m\xe9thode consiste \xe0 utiliser la s\xe9rie altern\xe9e de Leibniz (d\xe9veloppement de arctan(1))\xa0:', '\n')
# (u"Si vous recherchez une m\xe9thode remarquable, consultez la m\xe9thode de Srinivasa Ramanujan. Elle converge si vite que vous aurez r\xe9ellement besoin d'une pr\xe9cision math\xe9matique arbitraire pour afficher les d\xe9cimales. Vous pouvez faire cela avec le module Python standard decimal, si cela vous int\xe9resse.", '\n')
# (u"Le calcul num\xe9rique d'une int\xe9grale peut s'av\xe9rer \xe9pineux et parfois, il est plus facile d'\xe9valuer le r\xe9sultat par le biais d'une approximation. Par exemple, supposons que nous voulions voir ce que donne l'int\xe9grale\xa0:", '\n')
# (u'[<matplotlib.lines.Line2D at 0x7f0f5012f590>] ', '\n')
# (u' ', '\n')
# (u"La librairie Scipy poss\xe8de une fonction de calcul num\xe9rique d'int\xe9grale nomm\xe9e quad() (on appelle parfois quadrature ce genre de calculs), que nous pouvons utiliser ici\xa0:", '\n')
# (u'Vous avez aussi des int\xe9grateurs 2D et 3D dans Scipy. Pour en savoir plus, consultez la documentation.', '\n')
# (u'Nous avons tr\xe8s souvent recours aux techniques FFT (Fast Fourier Transform - transform\xe9e de Fourier rapide) pour nous aider \xe0 extraire un signal \xe0 partir de donn\xe9es \xab\xa0bruit\xe9es\xa0\xbb\xa0:', '\n')
# (u' ', '\n')
# (u'Dans Scipy, il existe des fonctions additionnelles qui g\xe8rent le traitement du signal.', '\n')
# (u'\xc0 suivre (en cours de traduction)\xa0:', '\n')
# (u'Un grand merci \xe0 Alex et Tess pour tout\xa0!', '\n')
# (u'Remerciements chaleureux \xe0 Barbara Muller et Tom Tarman pour leurs pr\xe9cieuses suggestions.', '\n')
# (u"Ce document (version originale\xa0: A Crash Course in Python for Scientists) est publi\xe9 sous licence Creative Commons Paternit\xe9 - Partage \xe0 l'identique 3.0 non transpos\xe9. Ce document est publi\xe9 gratuitement, avec l'espoir qu'il sera utile. Merci d'envisager un don au Fonds de soutien en m\xe9moire de John Hunter - article en fran\xe7ais \xe0 cet endroit.", '\n')
# (u"Sandia est un laboratoire pluridisciplinaire g\xe9r\xe9 par la Sandia Corporation\xae, une filiale de la Lockheed Martin Company\xae, pour le compte des \xc9tats-Unis d'Am\xe9rique, d\xe9partement de l'\xc9nergie, administration de la S\xfbret\xe9 Nucl\xe9aire, sous contrat n\xb0 DE-AC04-94AL85000.", '\n')
# (u'Nous remercions Rick Muller qui nous a aimablement autoris\xe9 \xe0 traduire son cours "A Crash Course in Python for Scientists".', '\n')
# (u'Nos remerciements \xe0 Rapha\xebl SEBAN (tarball69) pour la traduction et \xe0 Fabien (f-leb) pour la mise au gabarit. Merci aussi \xe0 S\xe9bastien (-Nikopol-) pour son renfort sur les points math\xe9matiques d\xe9licats dans cet article.', '\n')
# (u'Nous remercions \xe9galement Malick SECK (milkoseck) pour sa relecture orthographique.', '\n')
# (u'Vous avez aim\xe9 ce tutoriel\xa0? Alors partagez-le en cliquant sur les boutons suivants\xa0: \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0', '\n')
# (u'En compl\xe9ment sur Developpez.com', '\n')
# (u"\n\n\n\n\nLe contenu de cet article est r\xe9dig\xe9 par Rick Muller et est mis \xe0 disposition selon les termes de la \nLicence Creative Commons Attribution - Partage dans les M\xeames Conditions 3.0 non transpos\xe9.\nLes logos Developpez.com, en-t\xeate, pied de page, css, et look & feel de l'article sont Copyright \xa9 2013 Developpez.com.", '\n')
# (u'\n\t\t\t\t\t\t\tResponsable\n\t\t\t\t\t\t\t\t\t\t\tde la rubrique Python :\n\n\t\t\t\t\t\t\tle Service Publications -\n\t\t\t\n\t\t\t\t\n\t<!--\n\tCh=new Array(4);Res=new Array(4);\n\tCh[0]=\'le_club_des_developeur\';Ch[1]=\'\xd9\xc6\xc8\xcf\xe0\xe4\';\n\tCh[2]=\'\xac\xd7\xc4\xc7\xcd\xd8\xd6\xc8\xd3\xd3\';Ch[3]=\'\xd0\xca\xd5\xc8\xd8\xe4\xd2\xcf\xc9\xdf\xa1\xc2\xd3\xd2\';\n\tfor(y=1;y<4;y++){Res[y]="";for(x=0;x<Ch[y].length;x++)\n\tRes[y]+=String.fromCharCode(Ch[y].charCodeAt(x)-Ch[0].charCodeAt(x));}\n\tvar st = \'<a href="\'+Res[1]+\':python\'+Res[2]+\'-\'+Res[3]+\'">Contacter par email<\\/a>\';\tdocument.write(st);\n\t//-->\n\t\n', '\n')
# (u'Nous contacter', '\n')
# (u'Participez', '\n')
# (u'Informations l\xe9gales', '\n')
# (u'Forum Python', '\n')
# (u'Blogs', '\n')
# (u'H\xe9bergement', '\n')
# (u'PlanetHosterIkoula', '\n')
# (u'Copyright \xa9 2000-2014 - www.developpez.com', '\n')

# %%
import goslate

gs = goslate.Goslate()

print gs.get_languages()['fr']

gs.translate('etreint','en','fr')

def t(word):
    print word,gs.translate(word,'en','fr'), "\n"
    return gs.translate(word,'en','fr')
