# %%
# %pylab inline
from functions import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
roots = [-4,5]
function = functionFromRoots(roots)
function.plot()
# Out:
# Here are the factors: [x + 4, x - 5]
# Here is the polynomial x^{2} - x - 20

# %% [markdown]
# What happens if we change the x^2?

# %%
function.change(0)

# %% [markdown]
# Today I learnedhelp(functionFromRoots)

# %%
function
