# %% [markdown]
# One-hour group project to base a company on an idea in that day's paper. One columnist had written about choosing who to vote for as being like dating so we proposed a 'dating' website for candidates in the local elections.
#
#
# - Speed date -> candidates have short videos where they give their pitch
# - Single date -> arrange an appointment with the candidate about an issue you care about
# - Group date -> list venues where candidate is scheduled to appear in public
# - Blind date -> You choose your values using Belbin scoring on a range of categories and find the candidate whose spatial preferences*(see below) match yours.
# - Get-to-know-you date -> candidate bios
#
#
# _*Each spot is given a point in n-dimensional space and the distance is calculated to each candidate's preference_

# %%
from IPython.display import Image

# by default Image data are embedded
Embed      = Image(    'votehome.jpg')
Embed

# %% [markdown]
# # Spatial Preferences
# ### Question 1
# #### Please allocate* 10 points to the folllowing projects to reflect their importance to you:
# - skate park
# - finish ring road
# - close pubs an hour earlier
#
# _*Allocating points compels people to choose between their favourites as opposed to, for example, ranking 1-10 where someone could choose at the extremes on each issue_

# %%
from IPython.display import Image

# by default Image data are embedded
Embed      = Image(    'sp.png')
Embed

# %%
print b

# %%
print c

# %%
print d
