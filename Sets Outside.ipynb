# %% [markdown]
# #Big
# ###Medium
# ######Small

# %%
# %pylab inline
from sets import *
# Out:
# Populating the interactive namespace from numpy and matplotlib
# hi

# %%
a = set("badder")
print a
print len (a),  "is the length of the set a"
# Out:
# set(['a', 'r', 'b', 'e', 'd'])
# 5 is the length of the set a

# %%
b = set("dumb")
c = set("board")

sets = [a,b,c]

venn(sets)
